# %%
import random
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time

# %%
NUM_ALIGNMENTS = 7 #number of alignment values (0,4,16,64,256,1024,4096)
tlb = pd.read_csv('tlb.csv')
memory = pd.read_csv('Memory_Sections.csv')

# %%
tlb.columns
# Out:
# Index(['Name', 'Memory Type', 'Min Size', 'Size in KB', 'Start Address'], dtype='object')

# %%
memory
# Out:
#    Name   TLB  Size  Alignment  Start Address
# 0  Mem1  DDR1     3          0            NaN
# 1  Mem1  DDR1     4          0            NaN
# 2  Mem1  DDR1     5          0            NaN
# 3  Mem1  DDR1     1          0            NaN
# 4  Mem1  DDR1     2          0            NaN
# 5  Mem1  DDR1     2          0            NaN

# %%
# merge function
def Merge(a, b, order):
    c = pd.DataFrame(columns = memory.columns)
    while((len(a)!= 0) and (len(b) != 0)):
        if (b.loc[b.first_valid_index()][order] > a.loc[a.first_valid_index()][order]):
            #add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            #remove b[0] from b
            b = b.drop(b.first_valid_index())   
        else:
            # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index())
 
    while (len(a) != 0):     
        # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index()) 
    while (len(b) != 0):     
        # add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            #rmeove a[0] from a
            b = b.drop(b.first_valid_index())  
    return c

# %%
# merge function
def Merge_Backwards(a, b, order):
    c = pd.DataFrame(columns = memory.columns)
    while((len(a)!= 0) and (len(b) != 0)):
        if (b.loc[b.first_valid_index()][order] < a.loc[a.first_valid_index()][order]):
            #add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            #remove b[0] from b
            b = b.drop(b.first_valid_index())   
        else:
            # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index())
 
    while (len(a) != 0):     
        # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index()) 
    while (len(b) != 0):     
        # add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            #rmeove a[0] from a
            b = b.drop(b.first_valid_index())  
    return c

# %%
def MergeSort(mem, order):
    n = len(mem)
    if ( n == 1 ): return mem
    
    l1 = mem[0:math.floor(n/2)]
    l2 = mem[math.floor(n/2) : n]

    l1 = MergeSort( l1, order )
    l2 = MergeSort( l2, order )

    return Merge( l1, l2, order )

# %%
def MergeSort_Backwards(mem, order):
    n = len(mem)
    if ( n == 1 ): return mem
    
    l1 = mem[0:math.floor(n/2)]
    l2 = mem[math.floor(n/2) : n]

    l1 = MergeSort_Backwards( l1, order )
    l2 = MergeSort_Backwards( l2, order )

    return Merge_Backwards( l1, l2, order )

# %%
from numpy import roots
# merge function
def Merge_Alignment(a, b, order):
    # 4,16,64,256,1024,4096
    alignment_cnt = [0,0,0,0,0,0,0]
    c = pd.DataFrame(columns = memory.columns)
    while((len(a)!= 0) and (len(b) != 0)):
        if (b.loc[b.first_valid_index()][order] > a.loc[a.first_valid_index()][order]):
            #add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            alignment_cnt[int(math.log(c.loc[c.last_valid_index()][order], 4))]+=1
            #remove b[0] from b
            b = b.drop(b.first_valid_index())   
        else:
            # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            alignment_cnt[int(math.log(c.loc[c.last_valid_index()][order], 4))]+=1
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index())
 
    while (len(a) != 0):     
        # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            alignment_cnt[int(math.log(c.loc[c.last_valid_index()][order], 4))]+=1
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index()) 
    while (len(b) != 0):     
        # add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            alignment_cnt[int(math.log(c.loc[c.last_valid_index()][order], 4))]+=1
            #rmeove a[0] from a
            b = b.drop(b.first_valid_index())  
    
    return c, alignment_cnt

# %%
def MergeSort_Alignment(mem):
    n = len(mem)
    if ( n == 1 ): return mem
    
    l1 = mem[0:math.floor(n/2)]
    l2 = mem[math.floor(n/2) : n]

    l1 = MergeSort( l1, 'Alignment' )
    l2 = MergeSort( l2, 'Alignment' )

    return Merge_Alignment( l1, l2, 'Alignment' )

# %%
#mergeSort on alignment
c, alignment_cnt = MergeSort_Alignment(memory)
print(c, alignment_cnt)
# Out:
# B Size:  256
# A Size:  256
# Added:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# Added:  4
# B Size:  4
# A Size:  4096
# Added:  4096
# Added:  4
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4
# A Size:  1024
# Added:  1024
# Added:  4
# B Size:  4096
# A Size:  256
# Added:  4096
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  256
# A Size:  256
# Added:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# Added:  4
# B Size:  4
# A Size:  4096
# Added:  4096
# Added:  4
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4
# A Size:  1024
# Added:  1024
# Added:  4
# B Size:  4096
# A Size:  256
# Added:  4096
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  4096
# A Size:  4096
# Added:  4096
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  1024
# A Size:  1024
# Added:  1024
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# Added:  4
# B Size:  256
# A Size:  256
# Added:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# Added:  4
# B Size:  4
# A Size:  4096
# Added:  4096
# Added:  4
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4
# A Size:  1024
# Added:  1024
# Added:  4
# B Size:  4096
# A Size:  256
# Added:  4096
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  256
# A Size:  256
# Added:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# Added:  4
# B Size:  4
# A Size:  4096
# Added:  4096
# Added:  4
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4
# A Size:  1024
# Added:  1024
# Added:  4
# B Size:  4096
# A Size:  256
# Added:  4096
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  4096
# A Size:  4096
# Added:  4096
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  1024
# A Size:  1024
# Added:  1024
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# Added:  4
# B Size:  4096
# A Size:  4096
# Added:  4096
# B Size:  4096
# A Size:  4096
# Added:  4096
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  1024
# A Size:  1024
# Added:  1024
# B Size:  1024
# A Size:  1024
# Added:  1024
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# Added:  4
# Added:  4
# Added:  4
#      Name   TLB Size Alignment Start Address
# 4    Mem5  DDR1    2      4096           NaN
# 10  Mem11  DDR1    5      4096           NaN
# 16  Mem17  DDR1    3      4096           NaN
# 22  Mem23  DDR1    5      4096           NaN
# 3    Mem4  DDR1    1      1024           NaN
# 9   Mem10  DDR1    4      1024           NaN
# 15  Mem16  DDR1    4      1024           NaN
# 21  Mem22  DDR1    4      1024           NaN
# 1    Mem2  DDR1    4       256           NaN
# 2    Mem3  DDR1    5       256           NaN
# 7    Mem8  DDR1    2       256           NaN
# 8    Mem9  DDR1    3       256           NaN
# 13  Mem14  DDR1    5       256           NaN
# 14  Mem15  DDR1    3       256           NaN
# 19  Mem20  DDR1    4       256           NaN
# 20  Mem21  DDR1    6       256           NaN
# 0    Mem1  DDR1    3         4           NaN
# 5    Mem6  DDR1    2         4           NaN
# 6    Mem7  DDR1    2         4           NaN
# 11  Mem12  DDR1    5         4           NaN
# 12  Mem13  DDR1    5         4           NaN
# 17  Mem18  DDR1    2         4           NaN
# 18  Mem19  DDR1    1         4           NaN
# 23  Mem24  DDR1    5         4           NaN [0, 8, 0, 0, 8, 4, 4]

# %%
#create a list of aligment organized arrays
df0 = pd.DataFrame(columns = memory.columns)
df1 = pd.DataFrame(columns = memory.columns)
df2 = pd.DataFrame(columns = memory.columns)
df3 = pd.DataFrame(columns = memory.columns)
df4 = pd.DataFrame(columns = memory.columns)
df5 = pd.DataFrame(columns = memory.columns)
df6 = pd.DataFrame(columns = memory.columns)

AlignmentLists = [df0,df1,df2,df3,df4,df5,df6]

# %%
#split into data frames by alignment
first = 0
for i in range (NUM_ALIGNMENTS):
    AlignmentLists[NUM_ALIGNMENTS-1-i] = c[first:first+alignment_cnt[NUM_ALIGNMENTS-1-i]]
    first = first + alignment_cnt[NUM_ALIGNMENTS-1-i]

# %%
print(alignment_cnt)
print(AlignmentLists[0], "\n")
print(AlignmentLists[1], "\n")
print(AlignmentLists[2], "\n")
print(AlignmentLists[3], "\n")
print(AlignmentLists[4], "\n")
print(AlignmentLists[5], "\n")
print(AlignmentLists[6], "\n")
# Out:
# [0, 8, 0, 0, 8, 4, 4]
# Empty DataFrame
# Columns: [Name, TLB, Size, Alignment, Start Address]
# Index: []
#
#      Name   TLB Size Alignment Start Address
# 0    Mem1  DDR1    3         4           NaN
# 5    Mem6  DDR1    2         4           NaN
# 6    Mem7  DDR1    2         4           NaN
# 11  Mem12  DDR1    5         4           NaN
# 12  Mem13  DDR1    5         4           NaN
# 17  Mem18  DDR1    2         4           NaN
# 18  Mem19  DDR1    1         4           NaN
# 23  Mem24  DDR1    5         4           NaN
#
# Empty DataFrame
# Columns: [Name, TLB, Size, Alignment, Start Address]
# Index: []
#
# Empty DataFrame
# Columns: [Name, TLB, Size, Alignment, Start Address]
# Index: []
#
#      Name   TLB Size Alignment Start Address
# 1    Mem2  DDR1    4       256           NaN
# 2    Mem3  DDR1    5       256           NaN
# 7    Mem8  DDR1    2       256           NaN
# 8    Mem9  DDR1    3       256           NaN
# 13  Mem14  DDR1    5       256           NaN
# 14  Mem15  DDR1    3       256           NaN
# 19  Mem20  DDR1    4       256           NaN
# 20  Mem21  DDR1    6       256           NaN
#
#      Name   TLB Size Alignment Start Address
# 3    Mem4  DDR1    1      1024           NaN
# 9   Mem10  DDR1    4      1024           NaN
# 15  Mem16  DDR1    4      1024           NaN
# 21  Mem22  DDR1    4      1024           NaN
#
#      Name   TLB Size Alignment Start Address
# 4    Mem5  DDR1    2      4096           NaN
# 10  Mem11  DDR1    5      4096           NaN
# 16  Mem17  DDR1    3      4096           NaN
# 22  Mem23  DDR1    5      4096           NaN

# %%
#sort each alignment df by size in decending order
order = 'Size'
for i in range (NUM_ALIGNMENTS):
    if(len(AlignmentLists[i])>1):
        AlignmentLists[i] = MergeSort(AlignmentLists[i], order)
# Out:
# B Size:  2
# A Size:  3
# Added:  3
# Added:  2
# B Size:  5
# A Size:  2
# Added:  5
# Added:  2
# B Size:  5
# A Size:  3
# Added:  5
# B Size:  2
# A Size:  3
# Added:  3
# B Size:  2
# A Size:  2
# Added:  2
# Added:  2
# B Size:  2
# A Size:  5
# Added:  5
# Added:  2
# B Size:  5
# A Size:  1
# Added:  5
# Added:  1
# B Size:  5
# A Size:  5
# Added:  5
# B Size:  5
# A Size:  2
# Added:  5
# B Size:  1
# A Size:  2
# Added:  2
# Added:  1
# B Size:  5
# A Size:  5
# Added:  5
# B Size:  5
# A Size:  3
# Added:  5
# B Size:  5
# A Size:  3
# Added:  5
# B Size:  2
# A Size:  3
# Added:  3
# B Size:  2
# A Size:  2
# Added:  2
# B Size:  2
# A Size:  2
# Added:  2
# Added:  2
# Added:  1
# B Size:  5
# A Size:  4
# Added:  5
# Added:  4
# B Size:  3
# A Size:  2
# Added:  3
# Added:  2
# B Size:  3
# A Size:  5
# Added:  5
# B Size:  3
# A Size:  4
# Added:  4
# Added:  3
# Added:  2
# B Size:  3
# A Size:  5
# Added:  5
# Added:  3
# B Size:  6
# A Size:  4
# Added:  6
# Added:  4
# B Size:  6
# A Size:  5
# Added:  6
# B Size:  4
# A Size:  5
# Added:  5
# B Size:  4
# A Size:  3
# Added:  4
# Added:  3
# B Size:  6
# A Size:  5
# Added:  6
# B Size:  5
# A Size:  5
# Added:  5
# B Size:  5
# A Size:  4
# Added:  5
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  3
# Added:  4
# B Size:  3
# A Size:  3
# Added:  3
# B Size:  3
# A Size:  2
# Added:  3
# Added:  2
# B Size:  4
# A Size:  1
# Added:  4
# Added:  1
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  1
# Added:  4
# B Size:  4
# A Size:  1
# Added:  4
# Added:  1
# B Size:  5
# A Size:  2
# Added:  5
# Added:  2
# B Size:  5
# A Size:  3
# Added:  5
# Added:  3
# B Size:  5
# A Size:  5
# Added:  5
# B Size:  5
# A Size:  2
# Added:  5
# B Size:  3
# A Size:  2
# Added:  3
# Added:  2

# %%
#getNextMinAddress returns the next min address possible for the specified entry i in the current Align List
def getNextStartAddress(AlignList, i):
    if(i==0):
        #assign address to min TLB value, for now use 0
        StartAddress = 0 
    else:
        min_address = (AlignList.iloc[i-1]['Start Address'] + AlignList.iloc[i-1]['Size'])
        alignment = AlignList.iloc[i]['Alignment']
        StartAddress = (min_address + alignment) - (min_address + alignment)%alignment
    return StartAddress

# %%
#assign start addresses starting from largest to smallest and merge
for i in range (NUM_ALIGNMENTS):
    if (len(AlignmentLists[NUM_ALIGNMENTS-1-i])!=0):
        first_nonzero = i
        break
for j in range(len(AlignmentLists[NUM_ALIGNMENTS-1-i])):
    AlignmentLists[NUM_ALIGNMENTS-1-i].iloc[j]['Start Address'] = getNextStartAddress(AlignmentLists[NUM_ALIGNMENTS-1-i],j)
print(AlignmentLists[NUM_ALIGNMENTS-1-i])
# Out:
#      Name   TLB Size Alignment Start Address
# 10  Mem11  DDR1    5      4096             0
# 22  Mem23  DDR1    5      4096          4096
# 16  Mem17  DDR1    3      4096          8192
# 4    Mem5  DDR1    2      4096         12288

# %%
#getNextMinAddress returns the next min address possible for the specified entry i in the current Align List
def getNextStartAddress_Merge(AlignList, i, alignment):
    if(i==0):
        #assign address to min TLB value, for now use 0
        StartAddress = 0 
    else:
        min_address = (AlignList.iloc[i]['Start Address'] + AlignList.iloc[i]['Size'])
        StartAddress = (min_address + alignment) - (min_address + alignment)%alignment
    return StartAddress

# %%
# merge function
#b has addresses 
#a does not have addresses
def MergeAssignAddress(a, b, order):
    c = pd.DataFrame(columns = memory.columns)
    #assign first to b
    if(len(b)>0):
        #add b[0] to the end of c
        c = c.append(b.loc[b.first_valid_index()])
        #remove b[0] from b
        b = b.drop(b.first_valid_index()) 
    while((len(a)!= 0) and (len(b) != 0)):        
        #assign a address to the earliest possible next address in c
       # a.loc[a.first_valid_index()][order] =  c.loc[-1][order] +  c.loc[-1]['Size']
        a.loc[a.first_valid_index()][order] = getNextStartAddress_Merge(c, len(c)-1, a.loc[a.first_valid_index()]['Alignment'] )
       # if(len(b)>1):
        if(a.loc[a.first_valid_index()][order] + a.loc[a.first_valid_index()]['Size'] > b.loc[b.first_valid_index()][order]):
            #add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            #remove b[0] from b
            b = b.drop(b.first_valid_index())   
        else:
            # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index())

    while (len(a) != 0):     
        #assign a
        #assign a address to the earliest possible next address in c
        #a.loc[a.first_valid_index()][order] =  c.loc[-1][order] +  c.loc[-1]['Size']
        a.loc[a.first_valid_index()][order] = getNextStartAddress_Merge(c, len(c)-1, a.loc[a.first_valid_index()]['Alignment'] )
        # add a[0] to the end of c
        c = c.append(a.loc[a.first_valid_index()])
        #rmeove a[0] from a
        a = a.drop(a.first_valid_index()) 
    while (len(b) != 0): 
        # add b[0] to the end of c
        c = c.append(b.loc[b.first_valid_index()])
        #rmeove a[0] from a
        b = b.drop(b.first_valid_index())  
    return c

# %%
def MergeSort_AssignAddress(mem):
    n = len(mem)
    if ( n == 1 ): return mem
    
    l1 = mem[0:math.floor(n/2)]
    l2 = mem[math.floor(n/2) : n]

    l1 = MergeSort_AssignAddress( l1, 'Start Address' )
    l2 = MergeSort_AssignAddress( l2, 'Start Address' )

    return MergeAssignAddress( l1, l2, 'Start Address' )

# %%
def getData_average():
    ########## AVERAGE CASE IMPORT DATA #######################
    tlbs_average =  pd.read_csv('generated_tlbs_average_case.csv')
    tlbs_average = tlbs_average.dropna()
    memory_average = pd.read_csv('generated_memory_sections_average_case.csv')
    memory_average = memory_average.dropna()
    #format data 
    tlbs_average['Start Address'] = tlbs_average['Start Address'].apply(int, base=16)
    tlbs_average['Min Size'] = tlbs_average['Min Size'].apply(int, base=16)
    tlbs_average['Size In KB'] = tlbs_average['Size In KB'].apply(str)
    tlbs_average['Size In KB'] = tlbs_average['Size In KB'].apply(int, base=16)

    memory_average['Alignment'] = memory_average['Alignment'].apply(str)
    memory_average['Alignment'] = memory_average['Alignment'].apply(int, base=16)
    memory_average['Size'] = memory_average['Size'].apply(int, base=16)
    memory = memory_average
    ################## SORT TLBS ##################
    tlb = tlbs_average
    tlb = MergeSort_Backwards(tlb, 'Start Address')
    print(tlb)
    num_tlbs = len(tlb)
    ################# Divide Memory sections into TLBs ###############
    tlb_memlist = []
    temp = pd.DataFrame()
    for i in range(num_tlbs):
        temp = (memory_average.loc[memory_average['TLB'] == tlb.iloc[i]['Name']])
        tlb_memlist.append(temp)
        # memory_average.loc[memory_average['TLB'] == 'User_TLB_DDR_3_1']
    return tlbs_average, memory_average, tlb_memlist

# %%
########## AVERAGE CASE IMPORT DATA #######################
tlbs_average =  pd.read_csv('generated_tlbs_average_case.csv')
tlbs_average = tlbs_average.dropna()
memory_average = pd.read_csv('generated_memory_sections_average_case.csv')
memory_average = memory_average.dropna()
#format data 
tlbs_average['Start Address'] = tlbs_average['Start Address'].apply(int, base=16)
tlbs_average['Min Size'] = tlbs_average['Min Size'].apply(int, base=16)
tlbs_average['Size In KB'] = tlbs_average['Size In KB'].apply(str)
tlbs_average['Size In KB'] = tlbs_average['Size In KB'].apply(int, base=16)

memory_average['Alignment'] = memory_average['Alignment'].apply(str)
memory_average['Alignment'] = memory_average['Alignment'].apply(int, base=16)
memory_average['Size'] = memory_average['Size'].apply(int, base=16)
memory = memory_average

# %%
################## SORT TLBS ##################
tlb = tlbs_average
tlb = MergeSort_Backwards(tlb, 'Start Address')
print(tlb)
num_tlbs = len(tlb)
# Out:
#                 Name  TLB  Size  Alignment Start Address     Min Size  \
# 8   User_TLB_DDR_1_1  NaN   NaN        NaN             0  234109656.0
# 11  User_TLB_DDR_1_4  NaN   NaN        NaN     268435456  221239593.0
# 4   User_TLB_DDR_1_2  NaN   NaN        NaN     536870912  213966068.0
# 0   User_TLB_DDR_1_6  NaN   NaN        NaN     805306368  130464993.0
# 7   User_TLB_DDR_2_0  NaN   NaN        NaN    1073741824   55660258.0
# 23  User_TLB_DDR_2_1  NaN   NaN        NaN    1140850688   30086856.0
# 9   User_TLB_DDR_2_2  NaN   NaN        NaN    1207959552   22763020.0
# 14  User_TLB_DDR_2_4  NaN   NaN        NaN    1275068416   18718225.0
# 19  User_TLB_DDR_3_3  NaN   NaN        NaN    1342177280   14798201.0
# 22  User_TLB_DDR_3_1  NaN   NaN        NaN    1358954496   13082132.0
# 5   User_TLB_DDR_3_0  NaN   NaN        NaN    1375731712   10691621.0
# 10  User_TLB_DDR_3_2  NaN   NaN        NaN    1392508928    4956311.0
# 16  User_TLB_DDR_4_3  NaN   NaN        NaN    1409286144    3876510.0
# 20  User_TLB_DDR_4_2  NaN   NaN        NaN    1413480448    3828590.0
# 1   User_TLB_DDR_4_0  NaN   NaN        NaN    1417674752    3098236.0
# 12  User_TLB_DDR_4_1  NaN   NaN        NaN    1421869056    1273536.0
# 3   User_TLB_DDR_5_4  NaN   NaN        NaN    1426063360     220272.0
# 18  User_TLB_DDR_5_1  NaN   NaN        NaN    1426325504     199684.0
# 2   User_TLB_DDR_5_0  NaN   NaN        NaN    1426587648     131454.0
# 6   User_TLB_DDR_5_2  NaN   NaN        NaN    1426849792     123267.0
# 15  User_TLB_DDR_6_1  NaN   NaN        NaN    1427111936      64271.0
# 17  User_TLB_DDR_6_0  NaN   NaN        NaN    1427177472      57550.0
# 13  User_TLB_DDR_6_4  NaN   NaN        NaN    1427243008      53057.0
# 21  User_TLB_DDR_6_2  NaN   NaN        NaN    1427308544      37951.0
#
#     Size In KB
# 8     262144.0
# 11    262144.0
# 4     262144.0
# 0     262144.0
# 7      65536.0
# 23     65536.0
# 9      65536.0
# 14     65536.0
# 19     16384.0
# 22     16384.0
# 5      16384.0
# 10     16384.0
# 16      4096.0
# 20      4096.0
# 1       4096.0
# 12      4096.0
# 3        256.0
# 18       256.0
# 2        256.0
# 6        256.0
# 15        64.0
# 17        64.0
# 13        64.0
# 21        64.0

# %%
################# Divide Memory sections into TLBs ###############
tlb_memlist = []
temp = pd.DataFrame()
for i in range(num_tlbs):
    temp = (memory_average.loc[memory_average['TLB'] == tlb.iloc[i]['Name']])
    tlb_memlist.append(temp)
    # memory_average.loc[memory_average['TLB'] == 'User_TLB_DDR_3_1']

# %%
import time
def runMergeSort(memory):

    #create a list of aligment organized arrays
    df0 = pd.DataFrame(columns = memory.columns)
    df1 = pd.DataFrame(columns = memory.columns)
    df2 = pd.DataFrame(columns = memory.columns)
    df3 = pd.DataFrame(columns = memory.columns)
    df4 = pd.DataFrame(columns = memory.columns)
    df5 = pd.DataFrame(columns = memory.columns)
    df6 = pd.DataFrame(columns = memory.columns)

    AlignmentLists = [df0,df1,df2,df3,df4,df5,df6]
    st = time.perf_counter()
    #startTime = time.perf_counter()
    ############################################ START TIMING ####################################
    #mergeSort on alignment
    c, alignment_cnt = MergeSort_Alignment(memory)

    #split into data frames by alignment
    first = 0
    for i in range (NUM_ALIGNMENTS):
        AlignmentLists[NUM_ALIGNMENTS-1-i] = c[first:first+alignment_cnt[NUM_ALIGNMENTS-1-i]]
        first = first + alignment_cnt[NUM_ALIGNMENTS-1-i]

    #sort each alignment df by size in decending order
    order = 'Size'
    for i in range (NUM_ALIGNMENTS):
        if(len(AlignmentLists[i])>1):
            AlignmentLists[i] = MergeSort(AlignmentLists[i], order)    

    #assign start addresses starting from largest to smallest and merge
    for i in range (NUM_ALIGNMENTS):
        if (len(AlignmentLists[NUM_ALIGNMENTS-1-i])!=0):
            first_nonzero = i
            break
    for j in range(len(AlignmentLists[NUM_ALIGNMENTS-1-i])):
        AlignmentLists[NUM_ALIGNMENTS-1-i].set_value(AlignmentLists[NUM_ALIGNMENTS-1-i].index[j], 'Start Address',getNextStartAddress(AlignmentLists[NUM_ALIGNMENTS-1-i],j))

    #merge all
    b = AlignmentLists[NUM_ALIGNMENTS-1-first_nonzero]
    for j in range(first_nonzero+1,NUM_ALIGNMENTS):
        a = AlignmentLists[NUM_ALIGNMENTS-1-j-first_nonzero]
        b = MergeAssignAddress(a, b, 'Start Address')
    ############################################ END TIMING ####################################
    et = time.perf_counter()
    totalTime = et-st
    return b, totalTime

# %%
runtime = 0
tlb_average = pd.DataFrame()
memory_average = pd.DataFrame()
tlb_memlist = []
tlb_average, memory_average, tlb_memlist =  getData_average()
memory = memory_average
b, runtime = runMergeSort(memory_average)
print(runtime)
print(b)
# Out:
#                 Name  TLB  Size  Alignment Start Address     Min Size  \
# 8   User_TLB_DDR_1_1  NaN   NaN        NaN             0  234109656.0
# 11  User_TLB_DDR_1_4  NaN   NaN        NaN     268435456  221239593.0
# 4   User_TLB_DDR_1_2  NaN   NaN        NaN     536870912  213966068.0
# 0   User_TLB_DDR_1_6  NaN   NaN        NaN     805306368  130464993.0
# 7   User_TLB_DDR_2_0  NaN   NaN        NaN    1073741824   55660258.0
# 23  User_TLB_DDR_2_1  NaN   NaN        NaN    1140850688   30086856.0
# 9   User_TLB_DDR_2_2  NaN   NaN        NaN    1207959552   22763020.0
# 14  User_TLB_DDR_2_4  NaN   NaN        NaN    1275068416   18718225.0
# 19  User_TLB_DDR_3_3  NaN   NaN        NaN    1342177280   14798201.0
# 22  User_TLB_DDR_3_1  NaN   NaN        NaN    1358954496   13082132.0
# 5   User_TLB_DDR_3_0  NaN   NaN        NaN    1375731712   10691621.0
# 10  User_TLB_DDR_3_2  NaN   NaN        NaN    1392508928    4956311.0
# 16  User_TLB_DDR_4_3  NaN   NaN        NaN    1409286144    3876510.0
# 20  User_TLB_DDR_4_2  NaN   NaN        NaN    1413480448    3828590.0
# 1   User_TLB_DDR_4_0  NaN   NaN        NaN    1417674752    3098236.0
# 12  User_TLB_DDR_4_1  NaN   NaN        NaN    1421869056    1273536.0
# 3   User_TLB_DDR_5_4  NaN   NaN        NaN    1426063360     220272.0
# 18  User_TLB_DDR_5_1  NaN   NaN        NaN    1426325504     199684.0
# 2   User_TLB_DDR_5_0  NaN   NaN        NaN    1426587648     131454.0
# 6   User_TLB_DDR_5_2  NaN   NaN        NaN    1426849792     123267.0
# 15  User_TLB_DDR_6_1  NaN   NaN        NaN    1427111936      64271.0
# 17  User_TLB_DDR_6_0  NaN   NaN        NaN    1427177472      57550.0
# 13  User_TLB_DDR_6_4  NaN   NaN        NaN    1427243008      53057.0
# 21  User_TLB_DDR_6_2  NaN   NaN        NaN    1427308544      37951.0
#
#     Size In KB
# 8     262144.0
# 11    262144.0
# 4     262144.0
# 0     262144.0
# 7      65536.0
# 23     65536.0
# 9      65536.0
# 14     65536.0
# 19     16384.0
# 22     16384.0
# 5      16384.0
# 10     16384.0
# 16      4096.0
# 20      4096.0
# 1       4096.0
# 12      4096.0
# 3        256.0
# 18       256.0
# 2        256.0
# 6        256.0
# 15        64.0
# 17        64.0
# 13        64.0
# 21        64.0
# C:\Users\abige\Anaconda3\lib\site-packages\ipykernel_launcher.py:38: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Start Address:  0  Size:  12928576
# Start Address:  12931072  Size:  12912294
# Start Address:  25845760  Size:  12908347
# Start Address:  38756352  Size:  12707935
# Start Address:  51466240  Size:  12388929
# Start Address:  63856640  Size:  11677145
# Start Address:  75534336  Size:  11670948
# Start Address:  87207936  Size:  11269710
# Start Address:  98480128  Size:  11107380
# Start Address:  109588480  Size:  11007727
# Start Address:  120598528  Size:  10530661
# Start Address:  131129344  Size:  10192400
# Start Address:  141324288  Size:  10108804
# Start Address:  151433216  Size:  9302488
# Start Address:  160739328  Size:  9021180
# Start Address:  169762816  Size:  7012307
# Start Address:  176775168  Size:  6492840
# Start Address:  183271424  Size:  6439206
# Start Address:  189714432  Size:  5939745
# Start Address:  195657728  Size:  5490163
# Start Address:  201150464  Size:  4371666
# Start Address:  205524992  Size:  4240237
# Start Address:  209768448  Size:  4040434
# Start Address:  213811200  Size:  3915769
# Start Address:  217726976  Size:  3754458
# Start Address:  221483008  Size:  3394566
# Start Address:  224878592  Size:  3149025
# Start Address:  228028416  Size:  3124166
# Start Address:  231153664  Size:  3119130
# Start Address:  234274816  Size:  2918594
# Start Address:  237195264  Size:  2851881
# Start Address:  240050176  Size:  2677236
# Start Address:  242728960  Size:  2568215
# Start Address:  245301248  Size:  2507056
# Start Address:  247812096  Size:  2347775
# Start Address:  250163200  Size:  2346640
# Start Address:  252510208  Size:  2322686
# Start Address:  254836736  Size:  2303302
# Start Address:  257142784  Size:  2059808
# Start Address:  259203072  Size:  1999292
# Start Address:  261206016  Size:  1460467
# Start Address:  262668288  Size:  1420875
# Start Address:  264089600  Size:  1389545
# Start Address:  265482240  Size:  1305546
# Start Address:  266788864  Size:  992650
# Start Address:  267784192  Size:  855750
# Start Address:  268640256  Size:  844809
# Start Address:  269488128  Size:  838040
# Start Address:  270327808  Size:  831145
# Start Address:  271159296  Size:  829988
# Start Address:  271990784  Size:  704248
# Start Address:  272695296  Size:  704201
# Start Address:  273399808  Size:  686769
# Start Address:  274087936  Size:  681617
# Start Address:  274771968  Size:  667878
# Start Address:  275443712  Size:  658547
# Start Address:  276103168  Size:  653649
# Start Address:  276758528  Size:  577442
# Start Address:  277336064  Size:  572400
# Start Address:  277909504  Size:  532743
# Start Address:  278446080  Size:  524768
# Start Address:  278974464  Size:  521675
# Start Address:  279498752  Size:  516835
# Start Address:  280018944  Size:  488186
# Start Address:  280510464  Size:  486218
# Start Address:  280997888  Size:  468020
# Start Address:  281468928  Size:  458110
# Start Address:  281927680  Size:  371197
# Start Address:  282300416  Size:  346866
# Start Address:  282648576  Size:  324623
# Start Address:  282976256  Size:  298387
# Start Address:  283275264  Size:  296473
# Start Address:  283574272  Size:  295875
# Start Address:  283873280  Size:  244033
# Start Address:  284119040  Size:  229119
# Start Address:  284348416  Size:  226393
# Start Address:  284577792  Size:  208798
# Start Address:  284786688  Size:  202065
# Start Address:  284991488  Size:  196382
# Start Address:  285188096  Size:  195058
# Start Address:  285384704  Size:  189949
# Start Address:  285577216  Size:  181295
# Start Address:  285761536  Size:  179611
# Start Address:  285941760  Size:  178762
# Start Address:  286121984  Size:  177960
# Start Address:  286302208  Size:  175532
# Start Address:  286478336  Size:  174932
# Start Address:  286654464  Size:  174245
# Start Address:  286830592  Size:  148491
# Start Address:  286982144  Size:  140183
# Start Address:  287125504  Size:  104830
# Start Address:  287232000  Size:  90108
# Start Address:  287322112  Size:  86486
# Start Address:  287412224  Size:  79802
# Start Address:  287494144  Size:  79542
# Start Address:  287576064  Size:  79384
# Start Address:  287657984  Size:  76923
# Start Address:  287735808  Size:  70575
# Start Address:  287809536  Size:  65338
# Start Address:  287875072  Size:  63678
# Start Address:  287940608  Size:  61568
# Start Address:  288006144  Size:  60464
# Start Address:  288067584  Size:  59796
# Start Address:  288129024  Size:  51341
# Start Address:  288182272  Size:  48568
# Start Address:  288231424  Size:  19035
# Start Address:  288251904  Size:  16820
# Start Address:  288272384  Size:  14514
# Start Address:  288288768  Size:  12800
# Start Address:  288305152  Size:  12377
# Start Address:  288321536  Size:  11362
# Start Address:  288333824  Size:  9630
# Start Address:  288346112  Size:  9599
# Start Address:  288358400  Size:  8964
# Start Address:  288370688  Size:  8475
# Start Address:  288382976  Size:  8067
# Start Address:  288391168  Size:  6416
# Start Address:  288399360  Size:  5751
# Start Address:  288407552  Size:  4619
# Start Address:  288415744  Size:  3510
# Start Address:  288419840  Size:  2980
# Start Address:  288423936  Size:  2857
# Start Address:  288428032  Size:  2842
# Start Address:  288432128  Size:  2647
# Start Address:  288436224  Size:  2560
# Start Address:  288440320  Size:  2558
# Start Address:  288444416  Size:  2382
# Start Address:  288448512  Size:  2236
# Start Address:  288452608  Size:  2105
# Start Address:  288456704  Size:  1791
# Start Address:  288460800  Size:  1730
# Start Address:  288464896  Size:  1504
# Start Address:  288468992  Size:  1458
# Start Address:  288473088  Size:  1444
# Start Address:  288477184  Size:  1209
# Start Address:  288481280  Size:  1209
# Start Address:  288485376  Size:  1011
# Start Address:  288489472  Size:  984
# Start Address:  288493568  Size:  879
# Start Address:  288497664  Size:  797
# Start Address:  288501760  Size:  791
# Start Address:  288505856  Size:  503
# Start Address:  288509952  Size:  500
# Start Address:  288514048  Size:  487
# Start Address:  288518144  Size:  311
# Start Address:  288522240  Size:  271
