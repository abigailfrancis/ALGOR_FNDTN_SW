# %%
import random
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time

# %%
NUM_ALIGNMENTS = 7 #number of alignment values (0,4,16,64,256,1024,4096)
tlb = pd.read_csv('tlb.csv')
memory = pd.read_csv('Memory_Sections.csv')

# %%
tlb.columns
# Out:
# Index(['Name', 'Memory Type', 'Min Size', 'Size in KB', 'Start Address'], dtype='object')

# %%
memory
# Out:
#    Name   TLB  Size  Alignment  Start Address
# 0  Mem1  DDR1     3          0            NaN
# 1  Mem1  DDR1     4          0            NaN
# 2  Mem1  DDR1     5          0            NaN
# 3  Mem1  DDR1     1          0            NaN
# 4  Mem1  DDR1     2          0            NaN
# 5  Mem1  DDR1     2          0            NaN

# %%
# merge function
def Merge(a, b, order):
    c = pd.DataFrame(columns = memory.columns)
    while((len(a)!= 0) and (len(b) != 0)):
        if (b.loc[b.first_valid_index()][order] > a.loc[a.first_valid_index()][order]):
            #add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            #remove b[0] from b
            b = b.drop(b.first_valid_index())   
        else:
            # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index())
 
    while (len(a) != 0):     
        # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index()) 
    while (len(b) != 0):     
        # add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            #rmeove a[0] from a
            b = b.drop(b.first_valid_index())  
    return c

# %%
# merge function
def Merge_Backwards(a, b, order):
    c = pd.DataFrame(columns = memory.columns)
    while((len(a)!= 0) and (len(b) != 0)):
        if (b.loc[b.first_valid_index()][order] < a.loc[a.first_valid_index()][order]):
            #add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            #remove b[0] from b
            b = b.drop(b.first_valid_index())   
        else:
            # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index())
 
    while (len(a) != 0):     
        # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index()) 
    while (len(b) != 0):     
        # add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            #rmeove a[0] from a
            b = b.drop(b.first_valid_index())  
    return c

# %%
def MergeSort(mem, order):
    n = len(mem)
    if ( n == 1 ): return mem
    
    l1 = mem[0:math.floor(n/2)]
    l2 = mem[math.floor(n/2) : n]

    l1 = MergeSort( l1, order )
    l2 = MergeSort( l2, order )

    return Merge( l1, l2, order )

# %%
def MergeSort_Backwards(mem, order):
    n = len(mem)
    if ( n == 1 ): return mem
    
    l1 = mem[0:math.floor(n/2)]
    l2 = mem[math.floor(n/2) : n]

    l1 = MergeSort_Backwards( l1, order )
    l2 = MergeSort_Backwards( l2, order )

    return Merge_Backwards( l1, l2, order )

# %%
from numpy import roots
# merge function
def Merge_Alignment(a, b, order):
    # 4,16,64,256,1024,4096
    alignment_cnt = [0,0,0,0,0,0,0]
    c = pd.DataFrame(columns = memory.columns)
    while((len(a)!= 0) and (len(b) != 0)):
        if (b.loc[b.first_valid_index()][order] > a.loc[a.first_valid_index()][order]):
            #add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            alignment_cnt[int(math.log(c.loc[c.last_valid_index()][order], 4))]+=1
            #remove b[0] from b
            b = b.drop(b.first_valid_index())   
        else:
            # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            alignment_cnt[int(math.log(c.loc[c.last_valid_index()][order], 4))]+=1
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index())
 
    while (len(a) != 0):     
        # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            alignment_cnt[int(math.log(c.loc[c.last_valid_index()][order], 4))]+=1
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index()) 
    while (len(b) != 0):     
        # add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            alignment_cnt[int(math.log(c.loc[c.last_valid_index()][order], 4))]+=1
            #rmeove a[0] from a
            b = b.drop(b.first_valid_index())  
    
    return c, alignment_cnt

# %%
def MergeSort_Alignment(mem):
    n = len(mem)
    if ( n == 1 ): return mem
    
    l1 = mem[0:math.floor(n/2)]
    l2 = mem[math.floor(n/2) : n]

    l1 = MergeSort( l1, 'Alignment' )
    l2 = MergeSort( l2, 'Alignment' )

    return Merge_Alignment( l1, l2, 'Alignment' )

# %%
#mergeSort on alignment
c, alignment_cnt = MergeSort_Alignment(memory)
print(c, alignment_cnt)
# Out:
# B Size:  256
# A Size:  256
# Added:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# Added:  4
# B Size:  4
# A Size:  4096
# Added:  4096
# Added:  4
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4
# A Size:  1024
# Added:  1024
# Added:  4
# B Size:  4096
# A Size:  256
# Added:  4096
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  256
# A Size:  256
# Added:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# Added:  4
# B Size:  4
# A Size:  4096
# Added:  4096
# Added:  4
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4
# A Size:  1024
# Added:  1024
# Added:  4
# B Size:  4096
# A Size:  256
# Added:  4096
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  4096
# A Size:  4096
# Added:  4096
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  1024
# A Size:  1024
# Added:  1024
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# Added:  4
# B Size:  256
# A Size:  256
# Added:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# Added:  4
# B Size:  4
# A Size:  4096
# Added:  4096
# Added:  4
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4
# A Size:  1024
# Added:  1024
# Added:  4
# B Size:  4096
# A Size:  256
# Added:  4096
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  256
# A Size:  256
# Added:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# Added:  4
# B Size:  4
# A Size:  4096
# Added:  4096
# Added:  4
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4
# A Size:  1024
# Added:  1024
# Added:  4
# B Size:  4096
# A Size:  256
# Added:  4096
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  4096
# A Size:  4096
# Added:  4096
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  1024
# A Size:  1024
# Added:  1024
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# Added:  4
# B Size:  4096
# A Size:  4096
# Added:  4096
# B Size:  4096
# A Size:  4096
# Added:  4096
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  1024
# A Size:  1024
# Added:  1024
# B Size:  1024
# A Size:  1024
# Added:  1024
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# Added:  4
# Added:  4
# Added:  4
#      Name   TLB Size Alignment Start Address
# 4    Mem5  DDR1    2      4096           NaN
# 10  Mem11  DDR1    5      4096           NaN
# 16  Mem17  DDR1    3      4096           NaN
# 22  Mem23  DDR1    5      4096           NaN
# 3    Mem4  DDR1    1      1024           NaN
# 9   Mem10  DDR1    4      1024           NaN
# 15  Mem16  DDR1    4      1024           NaN
# 21  Mem22  DDR1    4      1024           NaN
# 1    Mem2  DDR1    4       256           NaN
# 2    Mem3  DDR1    5       256           NaN
# 7    Mem8  DDR1    2       256           NaN
# 8    Mem9  DDR1    3       256           NaN
# 13  Mem14  DDR1    5       256           NaN
# 14  Mem15  DDR1    3       256           NaN
# 19  Mem20  DDR1    4       256           NaN
# 20  Mem21  DDR1    6       256           NaN
# 0    Mem1  DDR1    3         4           NaN
# 5    Mem6  DDR1    2         4           NaN
# 6    Mem7  DDR1    2         4           NaN
# 11  Mem12  DDR1    5         4           NaN
# 12  Mem13  DDR1    5         4           NaN
# 17  Mem18  DDR1    2         4           NaN
# 18  Mem19  DDR1    1         4           NaN
# 23  Mem24  DDR1    5         4           NaN [0, 8, 0, 0, 8, 4, 4]

# %%
#create a list of aligment organized arrays
df0 = pd.DataFrame(columns = memory.columns)
df1 = pd.DataFrame(columns = memory.columns)
df2 = pd.DataFrame(columns = memory.columns)
df3 = pd.DataFrame(columns = memory.columns)
df4 = pd.DataFrame(columns = memory.columns)
df5 = pd.DataFrame(columns = memory.columns)
df6 = pd.DataFrame(columns = memory.columns)

AlignmentLists = [df0,df1,df2,df3,df4,df5,df6]

# %%
#split into data frames by alignment
first = 0
for i in range (NUM_ALIGNMENTS):
    AlignmentLists[NUM_ALIGNMENTS-1-i] = c[first:first+alignment_cnt[NUM_ALIGNMENTS-1-i]]
    first = first + alignment_cnt[NUM_ALIGNMENTS-1-i]

# %%
print(alignment_cnt)
print(AlignmentLists[0], "\n")
print(AlignmentLists[1], "\n")
print(AlignmentLists[2], "\n")
print(AlignmentLists[3], "\n")
print(AlignmentLists[4], "\n")
print(AlignmentLists[5], "\n")
print(AlignmentLists[6], "\n")
# Out:
# [0, 8, 0, 0, 8, 4, 4]
# Empty DataFrame
# Columns: [Name, TLB, Size, Alignment, Start Address]
# Index: []
#
#      Name   TLB Size Alignment Start Address
# 0    Mem1  DDR1    3         4           NaN
# 5    Mem6  DDR1    2         4           NaN
# 6    Mem7  DDR1    2         4           NaN
# 11  Mem12  DDR1    5         4           NaN
# 12  Mem13  DDR1    5         4           NaN
# 17  Mem18  DDR1    2         4           NaN
# 18  Mem19  DDR1    1         4           NaN
# 23  Mem24  DDR1    5         4           NaN
#
# Empty DataFrame
# Columns: [Name, TLB, Size, Alignment, Start Address]
# Index: []
#
# Empty DataFrame
# Columns: [Name, TLB, Size, Alignment, Start Address]
# Index: []
#
#      Name   TLB Size Alignment Start Address
# 1    Mem2  DDR1    4       256           NaN
# 2    Mem3  DDR1    5       256           NaN
# 7    Mem8  DDR1    2       256           NaN
# 8    Mem9  DDR1    3       256           NaN
# 13  Mem14  DDR1    5       256           NaN
# 14  Mem15  DDR1    3       256           NaN
# 19  Mem20  DDR1    4       256           NaN
# 20  Mem21  DDR1    6       256           NaN
#
#      Name   TLB Size Alignment Start Address
# 3    Mem4  DDR1    1      1024           NaN
# 9   Mem10  DDR1    4      1024           NaN
# 15  Mem16  DDR1    4      1024           NaN
# 21  Mem22  DDR1    4      1024           NaN
#
#      Name   TLB Size Alignment Start Address
# 4    Mem5  DDR1    2      4096           NaN
# 10  Mem11  DDR1    5      4096           NaN
# 16  Mem17  DDR1    3      4096           NaN
# 22  Mem23  DDR1    5      4096           NaN

# %%
#sort each alignment df by size in decending order
order = 'Size'
for i in range (NUM_ALIGNMENTS):
    if(len(AlignmentLists[i])>1):
        AlignmentLists[i] = MergeSort(AlignmentLists[i], order)
# Out:
# B Size:  2
# A Size:  3
# Added:  3
# Added:  2
# B Size:  5
# A Size:  2
# Added:  5
# Added:  2
# B Size:  5
# A Size:  3
# Added:  5
# B Size:  2
# A Size:  3
# Added:  3
# B Size:  2
# A Size:  2
# Added:  2
# Added:  2
# B Size:  2
# A Size:  5
# Added:  5
# Added:  2
# B Size:  5
# A Size:  1
# Added:  5
# Added:  1
# B Size:  5
# A Size:  5
# Added:  5
# B Size:  5
# A Size:  2
# Added:  5
# B Size:  1
# A Size:  2
# Added:  2
# Added:  1
# B Size:  5
# A Size:  5
# Added:  5
# B Size:  5
# A Size:  3
# Added:  5
# B Size:  5
# A Size:  3
# Added:  5
# B Size:  2
# A Size:  3
# Added:  3
# B Size:  2
# A Size:  2
# Added:  2
# B Size:  2
# A Size:  2
# Added:  2
# Added:  2
# Added:  1
# B Size:  5
# A Size:  4
# Added:  5
# Added:  4
# B Size:  3
# A Size:  2
# Added:  3
# Added:  2
# B Size:  3
# A Size:  5
# Added:  5
# B Size:  3
# A Size:  4
# Added:  4
# Added:  3
# Added:  2
# B Size:  3
# A Size:  5
# Added:  5
# Added:  3
# B Size:  6
# A Size:  4
# Added:  6
# Added:  4
# B Size:  6
# A Size:  5
# Added:  6
# B Size:  4
# A Size:  5
# Added:  5
# B Size:  4
# A Size:  3
# Added:  4
# Added:  3
# B Size:  6
# A Size:  5
# Added:  6
# B Size:  5
# A Size:  5
# Added:  5
# B Size:  5
# A Size:  4
# Added:  5
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  3
# Added:  4
# B Size:  3
# A Size:  3
# Added:  3
# B Size:  3
# A Size:  2
# Added:  3
# Added:  2
# B Size:  4
# A Size:  1
# Added:  4
# Added:  1
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  1
# Added:  4
# B Size:  4
# A Size:  1
# Added:  4
# Added:  1
# B Size:  5
# A Size:  2
# Added:  5
# Added:  2
# B Size:  5
# A Size:  3
# Added:  5
# Added:  3
# B Size:  5
# A Size:  5
# Added:  5
# B Size:  5
# A Size:  2
# Added:  5
# B Size:  3
# A Size:  2
# Added:  3
# Added:  2

# %%
#getNextMinAddress returns the next min address possible for the specified entry i in the current Align List
def getNextStartAddress(AlignList, i):
    if(i==0):
        #assign address to min TLB value, for now use 0
        StartAddress = 0 
    else:
        print(AlignList.iloc[i-1]['Start Address'], AlignList.iloc[i-1]['Size'])
        min_address = (AlignList.iloc[i-1]['Start Address'] + AlignList.iloc[i-1]['Size'])
        alignment = AlignList.iloc[i]['Alignment']
        StartAddress = (min_address + alignment) - (min_address + alignment)%alignment
    return StartAddress

# %%
#assign start addresses starting from largest to smallest and merge
for i in range (NUM_ALIGNMENTS):
    if (len(AlignmentLists[NUM_ALIGNMENTS-1-i])!=0):
        first_nonzero = i
        break
for j in range(len(AlignmentLists[NUM_ALIGNMENTS-1-i])):
    AlignmentLists[NUM_ALIGNMENTS-1-i].iloc[j]['Start Address'] = getNextStartAddress(AlignmentLists[NUM_ALIGNMENTS-1-i],j)
print(AlignmentLists[NUM_ALIGNMENTS-1-i])
# Out:
#      Name   TLB Size Alignment Start Address
# 10  Mem11  DDR1    5      4096             0
# 22  Mem23  DDR1    5      4096          4096
# 16  Mem17  DDR1    3      4096          8192
# 4    Mem5  DDR1    2      4096         12288

# %%
#getNextMinAddress returns the next min address possible for the specified entry i in the current Align List
def getNextStartAddress_Merge(AlignList, i, alignment):
    if(i==0):
        #assign address to min TLB value, for now use 0
        StartAddress = 0 
    else:
        print(AlignList.iloc[i]['Start Address'])
        print(AlignList.iloc[i]['Size'])
        min_address = (AlignList.iloc[i]['Start Address'] + AlignList.iloc[i]['Size'])
        StartAddress = (min_address + alignment) - (min_address + alignment)%alignment
    return StartAddress

# %%
# merge function
#b has addresses 
#a does not have addresses
def MergeAssignAddress(a, b, order):
    c = pd.DataFrame(columns = memory.columns)
    #assign first to b
    if(len(b)>0):
        #add b[0] to the end of c
        c = c.append(b.loc[b.first_valid_index()])
        #remove b[0] from b
        b = b.drop(b.first_valid_index()) 
    while((len(a)!= 0) and (len(b) != 0)):        
        #assign a address to the earliest possible next address in c
       # a.loc[a.first_valid_index()][order] =  c.loc[-1][order] +  c.loc[-1]['Size']
        a.loc[a.first_valid_index()][order] = getNextStartAddress_Merge(c, len(c)-1, a.loc[a.first_valid_index()]['Alignment'] )
        if(len(b)>1):
            if(a.loc[a.first_valid_index()][order] + a.loc[a.first_valid_index()]['Size'] > b.loc[b.first_valid_index()][order]):
                #add b[0] to the end of c
                c = c.append(b.loc[b.first_valid_index()])
                #remove b[0] from b
                b = b.drop(b.first_valid_index())   
            else:
                # add a[0] to the end of c
                c = c.append(a.loc[a.first_valid_index()])
                #rmeove a[0] from a
                a = a.drop(a.first_valid_index())

    while (len(a) != 0):     
        #assign a
        #assign a address to the earliest possible next address in c
        #a.loc[a.first_valid_index()][order] =  c.loc[-1][order] +  c.loc[-1]['Size']
        a.loc[a.first_valid_index()][order] = getNextStartAddress_Merge(c, len(c)-1, a.loc[a.first_valid_index()]['Alignment'] )
        # add a[0] to the end of c
        c = c.append(a.loc[a.first_valid_index()])
        #rmeove a[0] from a
        a = a.drop(a.first_valid_index()) 
    while (len(b) != 0):     
        # add b[0] to the end of c
        c = c.append(b.loc[b.first_valid_index()])
        #rmeove a[0] from a
        b = b.drop(b.first_valid_index())  
    return c

# %%
def MergeSort_AssignAddress(mem):
    n = len(mem)
    if ( n == 1 ): return mem
    
    l1 = mem[0:math.floor(n/2)]
    l2 = mem[math.floor(n/2) : n]

    l1 = MergeSort_AssignAddress( l1, 'Start Address' )
    l2 = MergeSort_AssignAddress( l2, 'Start Address' )

    return MergeAssignAddress( l1, l2, 'Start Address' )

# %%
def getData_average():
    ########## AVERAGE CASE IMPORT DATA #######################
    tlbs_average =  pd.read_csv('generated_tlbs_average_case.csv')
    tlbs_average = tlbs_average.dropna()
    memory_average = pd.read_csv('generated_memory_sections_average_case.csv')
    memory_average = memory_average.dropna()
    #format data 
    tlbs_average['Start Address'] = tlbs_average['Start Address'].apply(int, base=16)
    tlbs_average['Min Size'] = tlbs_average['Min Size'].apply(int, base=16)
    tlbs_average['Size In KB'] = tlbs_average['Size In KB'].apply(str)
    tlbs_average['Size In KB'] = tlbs_average['Size In KB'].apply(int, base=16)

    memory_average['Alignment'] = memory_average['Alignment'].apply(str)
    memory_average['Alignment'] = memory_average['Alignment'].apply(int, base=16)
    memory_average['Size'] = memory_average['Size'].apply(int, base=16)
    memory = memory_average
    ################## SORT TLBS ##################
    tlb = tlbs_average
    tlb = MergeSort_Backwards(tlb, 'Start Address')
    print(tlb)
    num_tlbs = len(tlb)
    ################# Divide Memory sections into TLBs ###############
    tlb_memlist = []
    temp = pd.DataFrame()
    for i in range(num_tlbs):
        temp = (memory_average.loc[memory_average['TLB'] == tlb.iloc[i]['Name']])
        tlb_memlist.append(temp)
        # memory_average.loc[memory_average['TLB'] == 'User_TLB_DDR_3_1']
    return tlbs_average, memory_average, tlb_memlist

# %%
########## AVERAGE CASE IMPORT DATA #######################
tlbs_average =  pd.read_csv('generated_tlbs_average_case.csv')
tlbs_average = tlbs_average.dropna()
memory_average = pd.read_csv('generated_memory_sections_average_case.csv')
memory_average = memory_average.dropna()
#format data 
tlbs_average['Start Address'] = tlbs_average['Start Address'].apply(int, base=16)
tlbs_average['Min Size'] = tlbs_average['Min Size'].apply(int, base=16)
tlbs_average['Size In KB'] = tlbs_average['Size In KB'].apply(str)
tlbs_average['Size In KB'] = tlbs_average['Size In KB'].apply(int, base=16)

memory_average['Alignment'] = memory_average['Alignment'].apply(str)
memory_average['Alignment'] = memory_average['Alignment'].apply(int, base=16)
memory_average['Size'] = memory_average['Size'].apply(int, base=16)
memory = memory_average

# %%
################## SORT TLBS ##################
tlb = tlbs_average
tlb = MergeSort_Backwards(tlb, 'Start Address')
print(tlb)
num_tlbs = len(tlb)
# Out:
#                 Name  TLB  Size  Alignment Start Address     Min Size  \
# 8   User_TLB_DDR_1_1  NaN   NaN        NaN             0  234109656.0
# 11  User_TLB_DDR_1_4  NaN   NaN        NaN     268435456  221239593.0
# 4   User_TLB_DDR_1_2  NaN   NaN        NaN     536870912  213966068.0
# 0   User_TLB_DDR_1_6  NaN   NaN        NaN     805306368  130464993.0
# 7   User_TLB_DDR_2_0  NaN   NaN        NaN    1073741824   55660258.0
# 23  User_TLB_DDR_2_1  NaN   NaN        NaN    1140850688   30086856.0
# 9   User_TLB_DDR_2_2  NaN   NaN        NaN    1207959552   22763020.0
# 14  User_TLB_DDR_2_4  NaN   NaN        NaN    1275068416   18718225.0
# 19  User_TLB_DDR_3_3  NaN   NaN        NaN    1342177280   14798201.0
# 22  User_TLB_DDR_3_1  NaN   NaN        NaN    1358954496   13082132.0
# 5   User_TLB_DDR_3_0  NaN   NaN        NaN    1375731712   10691621.0
# 10  User_TLB_DDR_3_2  NaN   NaN        NaN    1392508928    4956311.0
# 16  User_TLB_DDR_4_3  NaN   NaN        NaN    1409286144    3876510.0
# 20  User_TLB_DDR_4_2  NaN   NaN        NaN    1413480448    3828590.0
# 1   User_TLB_DDR_4_0  NaN   NaN        NaN    1417674752    3098236.0
# 12  User_TLB_DDR_4_1  NaN   NaN        NaN    1421869056    1273536.0
# 3   User_TLB_DDR_5_4  NaN   NaN        NaN    1426063360     220272.0
# 18  User_TLB_DDR_5_1  NaN   NaN        NaN    1426325504     199684.0
# 2   User_TLB_DDR_5_0  NaN   NaN        NaN    1426587648     131454.0
# 6   User_TLB_DDR_5_2  NaN   NaN        NaN    1426849792     123267.0
# 15  User_TLB_DDR_6_1  NaN   NaN        NaN    1427111936      64271.0
# 17  User_TLB_DDR_6_0  NaN   NaN        NaN    1427177472      57550.0
# 13  User_TLB_DDR_6_4  NaN   NaN        NaN    1427243008      53057.0
# 21  User_TLB_DDR_6_2  NaN   NaN        NaN    1427308544      37951.0
#
#     Size In KB
# 8     262144.0
# 11    262144.0
# 4     262144.0
# 0     262144.0
# 7      65536.0
# 23     65536.0
# 9      65536.0
# 14     65536.0
# 19     16384.0
# 22     16384.0
# 5      16384.0
# 10     16384.0
# 16      4096.0
# 20      4096.0
# 1       4096.0
# 12      4096.0
# 3        256.0
# 18       256.0
# 2        256.0
# 6        256.0
# 15        64.0
# 17        64.0
# 13        64.0
# 21        64.0

# %%
################# Divide Memory sections into TLBs ###############
tlb_memlist = []
temp = pd.DataFrame()
for i in range(num_tlbs):
    temp = (memory_average.loc[memory_average['TLB'] == tlb.iloc[i]['Name']])
    tlb_memlist.append(temp)
    # memory_average.loc[memory_average['TLB'] == 'User_TLB_DDR_3_1']

# %%
def runMergeSort(memory):
    #create a list of aligment organized arrays
    df0 = pd.DataFrame(columns = memory.columns)
    df1 = pd.DataFrame(columns = memory.columns)
    df2 = pd.DataFrame(columns = memory.columns)
    df3 = pd.DataFrame(columns = memory.columns)
    df4 = pd.DataFrame(columns = memory.columns)
    df5 = pd.DataFrame(columns = memory.columns)
    df6 = pd.DataFrame(columns = memory.columns)

    AlignmentLists = [df0,df1,df2,df3,df4,df5,df6]
    
    startTime = time.perf_counter()
    ############################################ START TIMING ####################################
    #mergeSort on alignment
    c, alignment_cnt = MergeSort_Alignment(memory)

    #split into data frames by alignment
    first = 0
    for i in range (NUM_ALIGNMENTS):
        AlignmentLists[NUM_ALIGNMENTS-1-i] = c[first:first+alignment_cnt[NUM_ALIGNMENTS-1-i]]
        first = first + alignment_cnt[NUM_ALIGNMENTS-1-i]

    #sort each alignment df by size in decending order
    order = 'Size'
    for i in range (NUM_ALIGNMENTS):
        if(len(AlignmentLists[i])>1):
            AlignmentLists[i] = MergeSort(AlignmentLists[i], order)    

    #assign start addresses starting from largest to smallest and merge
    for i in range (NUM_ALIGNMENTS):
        if (len(AlignmentLists[NUM_ALIGNMENTS-1-i])!=0):
            first_nonzero = i
            break
    for j in range(len(AlignmentLists[NUM_ALIGNMENTS-1-i])):
        AlignmentLists[NUM_ALIGNMENTS-1-i].set_value(AlignmentLists[NUM_ALIGNMENTS-1-i].index[j], 'Start Address',getNextStartAddress(AlignmentLists[NUM_ALIGNMENTS-1-i],j))

    #merge all
    b = AlignmentLists[NUM_ALIGNMENTS-1-first_nonzero]
    for j in range(first_nonzero+1,NUM_ALIGNMENTS):
        a = AlignmentLists[NUM_ALIGNMENTS-1-j-first_nonzero]
        b = MergeAssignAddress(a, b, 'Start Address')
    ############################################ END TIMING ####################################
    endTime = time.perf_counter()
    time = endTime-startTime 
    return b, time

# %%
c, alignment_cnt = MergeSort_Alignment(memory)

# %%
first = 0
for i in range (NUM_ALIGNMENTS):
    AlignmentLists[NUM_ALIGNMENTS-1-i] = c[first:first+alignment_cnt[NUM_ALIGNMENTS-1-i]]
    first = first + alignment_cnt[NUM_ALIGNMENTS-1-i]

# %%
#sort each alignment df by size in decending order
order = 'Size'
for i in range (NUM_ALIGNMENTS):
    if(len(AlignmentLists[i])>1):
        AlignmentLists[i] = MergeSort(AlignmentLists[i], order)

# %%
#assign start addresses starting from largest to smallest and merge
for i in range (NUM_ALIGNMENTS):
    if (len(AlignmentLists[NUM_ALIGNMENTS-1-i])!=0):
        first_nonzero = i
        break
for j in range(len(AlignmentLists[NUM_ALIGNMENTS-1-i])):
    print(AlignmentLists[NUM_ALIGNMENTS-1-i])
    AlignmentLists[NUM_ALIGNMENTS-1-i].set_value(AlignmentLists[NUM_ALIGNMENTS-1-i].index[j], 'Start Address',getNextStartAddress(AlignmentLists[NUM_ALIGNMENTS-1-i],j))
# Out:
#                                    Name               TLB      Size Alignment  \
# 533   Memory_Section_User_TLB_DDR_1_2_9  User_TLB_DDR_1_2  12928576      4096
# 868  Memory_Section_User_TLB_DDR_1_4_23  User_TLB_DDR_1_4  12912294      4096
# 901  Memory_Section_User_TLB_DDR_1_6_33  User_TLB_DDR_1_6  12908347      4096
# 377  Memory_Section_User_TLB_DDR_1_6_16  User_TLB_DDR_1_6  12707935      4096
# 817  Memory_Section_User_TLB_DDR_1_6_24  User_TLB_DDR_1_6  12388929      4096
# 517   Memory_Section_User_TLB_DDR_1_1_2  User_TLB_DDR_1_1  11677145      4096
# 118  Memory_Section_User_TLB_DDR_1_1_12  User_TLB_DDR_1_1  11670948      4096
# 319  Memory_Section_User_TLB_DDR_1_1_11  User_TLB_DDR_1_1  11269710      4096
# 206  Memory_Section_User_TLB_DDR_1_6_23  User_TLB_DDR_1_6  11107380      4096
# 513   Memory_Section_User_TLB_DDR_1_2_7  User_TLB_DDR_1_2  11007727      4096
# 807   Memory_Section_User_TLB_DDR_1_6_5  User_TLB_DDR_1_6  10530661      4096
# 462  Memory_Section_User_TLB_DDR_1_2_37  User_TLB_DDR_1_2  10192400      4096
# 15   Memory_Section_User_TLB_DDR_1_2_10  User_TLB_DDR_1_2  10108804      4096
# 414  Memory_Section_User_TLB_DDR_1_6_39  User_TLB_DDR_1_6   9302488      4096
# 392   Memory_Section_User_TLB_DDR_1_2_5  User_TLB_DDR_1_2   9021180      4096
# 547  Memory_Section_User_TLB_DDR_1_2_19  User_TLB_DDR_1_2   7012307      4096
# 518   Memory_Section_User_TLB_DDR_1_4_4  User_TLB_DDR_1_4   6492840      4096
# 706  Memory_Section_User_TLB_DDR_1_4_30  User_TLB_DDR_1_4   6439206      4096
# 375  Memory_Section_User_TLB_DDR_1_4_32  User_TLB_DDR_1_4   5939745      4096
# 276  Memory_Section_User_TLB_DDR_1_4_12  User_TLB_DDR_1_4   5490163      4096
# 155  Memory_Section_User_TLB_DDR_1_2_13  User_TLB_DDR_1_2   4371666      4096
# 7    Memory_Section_User_TLB_DDR_1_2_21  User_TLB_DDR_1_2   4240237      4096
# 467   Memory_Section_User_TLB_DDR_1_4_7  User_TLB_DDR_1_4   4040434      4096
# 673   Memory_Section_User_TLB_DDR_1_4_6  User_TLB_DDR_1_4   3915769      4096
# 349  Memory_Section_User_TLB_DDR_1_6_18  User_TLB_DDR_1_6   3754458      4096
# 482  Memory_Section_User_TLB_DDR_1_6_20  User_TLB_DDR_1_6   3394566      4096
# 1     Memory_Section_User_TLB_DDR_2_1_2  User_TLB_DDR_2_1   3149025      4096
# 885  Memory_Section_User_TLB_DDR_2_0_40  User_TLB_DDR_2_0   3124166      4096
# 510  Memory_Section_User_TLB_DDR_2_1_28  User_TLB_DDR_2_1   3119130      4096
# 24   Memory_Section_User_TLB_DDR_2_2_10  User_TLB_DDR_2_2   2918594      4096
# ..                                  ...               ...       ...       ...
# 520  Memory_Section_User_TLB_DDR_5_1_40  User_TLB_DDR_5_1      5751      4096
# 505   Memory_Section_User_TLB_DDR_5_2_7  User_TLB_DDR_5_2      4619      4096
# 858   Memory_Section_User_TLB_DDR_4_1_8  User_TLB_DDR_4_1      3510      4096
# 247  Memory_Section_User_TLB_DDR_5_1_18  User_TLB_DDR_5_1      2980      4096
# 821   Memory_Section_User_TLB_DDR_6_0_8  User_TLB_DDR_6_0      2857      4096
# 303  Memory_Section_User_TLB_DDR_6_0_28  User_TLB_DDR_6_0      2842      4096
# 683  Memory_Section_User_TLB_DDR_6_1_24  User_TLB_DDR_6_1      2647      4096
# 862  Memory_Section_User_TLB_DDR_6_4_39  User_TLB_DDR_6_4      2560      4096
# 230  Memory_Section_User_TLB_DDR_5_4_31  User_TLB_DDR_5_4      2558      4096
# 386  Memory_Section_User_TLB_DDR_6_4_19  User_TLB_DDR_6_4      2382      4096
# 757  Memory_Section_User_TLB_DDR_6_1_28  User_TLB_DDR_6_1      2236      4096
# 312   Memory_Section_User_TLB_DDR_5_1_2  User_TLB_DDR_5_1      2105      4096
# 64   Memory_Section_User_TLB_DDR_6_4_36  User_TLB_DDR_6_4      1791      4096
# 385  Memory_Section_User_TLB_DDR_6_0_27  User_TLB_DDR_6_0      1730      4096
# 454  Memory_Section_User_TLB_DDR_6_0_25  User_TLB_DDR_6_0      1504      4096
# 105   Memory_Section_User_TLB_DDR_6_4_3  User_TLB_DDR_6_4      1458      4096
# 422  Memory_Section_User_TLB_DDR_5_0_30  User_TLB_DDR_5_0      1444      4096
# 204  Memory_Section_User_TLB_DDR_5_0_13  User_TLB_DDR_5_0      1209      4096
# 782   Memory_Section_User_TLB_DDR_6_1_6  User_TLB_DDR_6_1      1209      4096
# 650  Memory_Section_User_TLB_DDR_5_2_10  User_TLB_DDR_5_2      1011      4096
# 112   Memory_Section_User_TLB_DDR_5_0_6  User_TLB_DDR_5_0       984      4096
# 760  Memory_Section_User_TLB_DDR_6_2_40  User_TLB_DDR_6_2       879      4096
# 815  Memory_Section_User_TLB_DDR_6_2_19  User_TLB_DDR_6_2       797      4096
# 609  Memory_Section_User_TLB_DDR_5_2_21  User_TLB_DDR_5_2       791      4096
# 93   Memory_Section_User_TLB_DDR_6_0_17  User_TLB_DDR_6_0       503      4096
# 187  Memory_Section_User_TLB_DDR_6_0_23  User_TLB_DDR_6_0       500      4096
# 280  Memory_Section_User_TLB_DDR_5_0_27  User_TLB_DDR_5_0       487      4096
# 231   Memory_Section_User_TLB_DDR_6_1_8  User_TLB_DDR_6_1       311      4096
# 578  Memory_Section_User_TLB_DDR_5_1_31  User_TLB_DDR_5_1       271      4096
# 169  Memory_Section_User_TLB_DDR_6_1_12  User_TLB_DDR_6_1        33      4096
#
#     Start Address
# 533      20000000
# 868      10000000
# 901      30000000
# 377      30c50000
# 817      3186f000
# 517             0
# 118        b23000
# 319       1645000
# 206      32440000
# 513      20c55000
# 807      32ed8000
# 462      216d5000
# 15       2208e000
# 414      338e3000
# 392      22a32000
# 547      232cd000
# 518      10c51000
# 706      11283000
# 375      118a8000
# 276      11e53000
# 155      2397d000
# 7        23da9000
# 467      12390000
# 673      1276b000
# 349      341c3000
# 482      34558000
# 1        44000000
# 885      40000000
# 510      44301000
# 24       48000000
# ..            ...
# 520      55040000
# 505      550c3000
# 858      54d28000
# 247      55042000
# 821      55110000
# 303      55111000
# 683      55100000
# 862      55120000
# 230      55012000
# 386      55121000
# 757      55101000
# 312      55043000
# 64       55122000
# 385      55112000
# 454      55113000
# 105      55123000
# 422      55086000
# 204      55087000
# 782      55102000
# 650      550c5000
# 112      55088000
# 760      55130000
# 815      55131000
# 609      550c6000
# 93       55114000
# 187      55115000
# 280      55089000
# 231      55103000
# 578      55044000
# 169      55104000
#
# [147 rows x 5 columns]
#                                    Name               TLB      Size Alignment  \
# 533   Memory_Section_User_TLB_DDR_1_2_9  User_TLB_DDR_1_2  12928576      4096
# 868  Memory_Section_User_TLB_DDR_1_4_23  User_TLB_DDR_1_4  12912294      4096
# 901  Memory_Section_User_TLB_DDR_1_6_33  User_TLB_DDR_1_6  12908347      4096
# 377  Memory_Section_User_TLB_DDR_1_6_16  User_TLB_DDR_1_6  12707935      4096
# 817  Memory_Section_User_TLB_DDR_1_6_24  User_TLB_DDR_1_6  12388929      4096
# 517   Memory_Section_User_TLB_DDR_1_1_2  User_TLB_DDR_1_1  11677145      4096
# 118  Memory_Section_User_TLB_DDR_1_1_12  User_TLB_DDR_1_1  11670948      4096
# 319  Memory_Section_User_TLB_DDR_1_1_11  User_TLB_DDR_1_1  11269710      4096
# 206  Memory_Section_User_TLB_DDR_1_6_23  User_TLB_DDR_1_6  11107380      4096
# 513   Memory_Section_User_TLB_DDR_1_2_7  User_TLB_DDR_1_2  11007727      4096
# 807   Memory_Section_User_TLB_DDR_1_6_5  User_TLB_DDR_1_6  10530661      4096
# 462  Memory_Section_User_TLB_DDR_1_2_37  User_TLB_DDR_1_2  10192400      4096
# 15   Memory_Section_User_TLB_DDR_1_2_10  User_TLB_DDR_1_2  10108804      4096
# 414  Memory_Section_User_TLB_DDR_1_6_39  User_TLB_DDR_1_6   9302488      4096
# 392   Memory_Section_User_TLB_DDR_1_2_5  User_TLB_DDR_1_2   9021180      4096
# 547  Memory_Section_User_TLB_DDR_1_2_19  User_TLB_DDR_1_2   7012307      4096
# 518   Memory_Section_User_TLB_DDR_1_4_4  User_TLB_DDR_1_4   6492840      4096
# 706  Memory_Section_User_TLB_DDR_1_4_30  User_TLB_DDR_1_4   6439206      4096
# 375  Memory_Section_User_TLB_DDR_1_4_32  User_TLB_DDR_1_4   5939745      4096
# 276  Memory_Section_User_TLB_DDR_1_4_12  User_TLB_DDR_1_4   5490163      4096
# 155  Memory_Section_User_TLB_DDR_1_2_13  User_TLB_DDR_1_2   4371666      4096
# 7    Memory_Section_User_TLB_DDR_1_2_21  User_TLB_DDR_1_2   4240237      4096
# 467   Memory_Section_User_TLB_DDR_1_4_7  User_TLB_DDR_1_4   4040434      4096
# 673   Memory_Section_User_TLB_DDR_1_4_6  User_TLB_DDR_1_4   3915769      4096
# 349  Memory_Section_User_TLB_DDR_1_6_18  User_TLB_DDR_1_6   3754458      4096
# 482  Memory_Section_User_TLB_DDR_1_6_20  User_TLB_DDR_1_6   3394566      4096
# 1     Memory_Section_User_TLB_DDR_2_1_2  User_TLB_DDR_2_1   3149025      4096
# 885  Memory_Section_User_TLB_DDR_2_0_40  User_TLB_DDR_2_0   3124166      4096
# 510  Memory_Section_User_TLB_DDR_2_1_28  User_TLB_DDR_2_1   3119130      4096
# 24   Memory_Section_User_TLB_DDR_2_2_10  User_TLB_DDR_2_2   2918594      4096
# ..                                  ...               ...       ...       ...
# 520  Memory_Section_User_TLB_DDR_5_1_40  User_TLB_DDR_5_1      5751      4096
# 505   Memory_Section_User_TLB_DDR_5_2_7  User_TLB_DDR_5_2      4619      4096
# 858   Memory_Section_User_TLB_DDR_4_1_8  User_TLB_DDR_4_1      3510      4096
# 247  Memory_Section_User_TLB_DDR_5_1_18  User_TLB_DDR_5_1      2980      4096
# 821   Memory_Section_User_TLB_DDR_6_0_8  User_TLB_DDR_6_0      2857      4096
# 303  Memory_Section_User_TLB_DDR_6_0_28  User_TLB_DDR_6_0      2842      4096
# 683  Memory_Section_User_TLB_DDR_6_1_24  User_TLB_DDR_6_1      2647      4096
# 862  Memory_Section_User_TLB_DDR_6_4_39  User_TLB_DDR_6_4      2560      4096
# 230  Memory_Section_User_TLB_DDR_5_4_31  User_TLB_DDR_5_4      2558      4096
# 386  Memory_Section_User_TLB_DDR_6_4_19  User_TLB_DDR_6_4      2382      4096
# 757  Memory_Section_User_TLB_DDR_6_1_28  User_TLB_DDR_6_1      2236      4096
# 312   Memory_Section_User_TLB_DDR_5_1_2  User_TLB_DDR_5_1      2105      4096
# 64   Memory_Section_User_TLB_DDR_6_4_36  User_TLB_DDR_6_4      1791      4096
# 385  Memory_Section_User_TLB_DDR_6_0_27  User_TLB_DDR_6_0      1730      4096
# 454  Memory_Section_User_TLB_DDR_6_0_25  User_TLB_DDR_6_0      1504      4096
# 105   Memory_Section_User_TLB_DDR_6_4_3  User_TLB_DDR_6_4      1458      4096
# 422  Memory_Section_User_TLB_DDR_5_0_30  User_TLB_DDR_5_0      1444      4096
# 204  Memory_Section_User_TLB_DDR_5_0_13  User_TLB_DDR_5_0      1209      4096
# 782   Memory_Section_User_TLB_DDR_6_1_6  User_TLB_DDR_6_1      1209      4096
# 650  Memory_Section_User_TLB_DDR_5_2_10  User_TLB_DDR_5_2      1011      4096
# 112   Memory_Section_User_TLB_DDR_5_0_6  User_TLB_DDR_5_0       984      4096
# 760  Memory_Section_User_TLB_DDR_6_2_40  User_TLB_DDR_6_2       879      4096
# 815  Memory_Section_User_TLB_DDR_6_2_19  User_TLB_DDR_6_2       797      4096
# 609  Memory_Section_User_TLB_DDR_5_2_21  User_TLB_DDR_5_2       791      4096
# 93   Memory_Section_User_TLB_DDR_6_0_17  User_TLB_DDR_6_0       503      4096
# 187  Memory_Section_User_TLB_DDR_6_0_23  User_TLB_DDR_6_0       500      4096
# 280  Memory_Section_User_TLB_DDR_5_0_27  User_TLB_DDR_5_0       487      4096
# 231   Memory_Section_User_TLB_DDR_6_1_8  User_TLB_DDR_6_1       311      4096
# 578  Memory_Section_User_TLB_DDR_5_1_31  User_TLB_DDR_5_1       271      4096
# 169  Memory_Section_User_TLB_DDR_6_1_12  User_TLB_DDR_6_1        33      4096
#
#     Start Address
# 533             0
# 868      10000000
# 901      30000000
# 377      30c50000
# 817      3186f000
# 517             0
# 118        b23000
# 319       1645000
# 206      32440000
# 513      20c55000
# 807      32ed8000
# 462      216d5000
# 15       2208e000
# 414      338e3000
# 392      22a32000
# 547      232cd000
# 518      10c51000
# 706      11283000
# 375      118a8000
# 276      11e53000
# 155      2397d000
# 7        23da9000
# 467      12390000
# 673      1276b000
# 349      341c3000
# 482      34558000
# 1        44000000
# 885      40000000
# 510      44301000
# 24       48000000
# ..            ...
# 520      55040000
# 505      550c3000
# 858      54d28000
# 247      55042000
# 821      55110000
# 303      55111000
# 683      55100000
# 862      55120000
# 230      55012000
# 386      55121000
# 757      55101000
# 312      55043000
# 64       55122000
# 385      55112000
# 454      55113000
# 105      55123000
# 422      55086000
# 204      55087000
# 782      55102000
# 650      550c5000
# 112      55088000
# 760      55130000
# 815      55131000
# 609      550c6000
# 93       55114000
# 187      55115000
# 280      55089000
# 231      55103000
# 578      55044000
# 169      55104000
#
# [147 rows x 5 columns]
# 0 12928576
#                                    Name               TLB      Size Alignment  \
# 533   Memory_Section_User_TLB_DDR_1_2_9  User_TLB_DDR_1_2  12928576      4096
# 868  Memory_Section_User_TLB_DDR_1_4_23  User_TLB_DDR_1_4  12912294      4096
# 901  Memory_Section_User_TLB_DDR_1_6_33  User_TLB_DDR_1_6  12908347      4096
# 377  Memory_Section_User_TLB_DDR_1_6_16  User_TLB_DDR_1_6  12707935      4096
# 817  Memory_Section_User_TLB_DDR_1_6_24  User_TLB_DDR_1_6  12388929      4096
# 517   Memory_Section_User_TLB_DDR_1_1_2  User_TLB_DDR_1_1  11677145      4096
# 118  Memory_Section_User_TLB_DDR_1_1_12  User_TLB_DDR_1_1  11670948      4096
# 319  Memory_Section_User_TLB_DDR_1_1_11  User_TLB_DDR_1_1  11269710      4096
# 206  Memory_Section_User_TLB_DDR_1_6_23  User_TLB_DDR_1_6  11107380      4096
# 513   Memory_Section_User_TLB_DDR_1_2_7  User_TLB_DDR_1_2  11007727      4096
# 807   Memory_Section_User_TLB_DDR_1_6_5  User_TLB_DDR_1_6  10530661      4096
# 462  Memory_Section_User_TLB_DDR_1_2_37  User_TLB_DDR_1_2  10192400      4096
# 15   Memory_Section_User_TLB_DDR_1_2_10  User_TLB_DDR_1_2  10108804      4096
# 414  Memory_Section_User_TLB_DDR_1_6_39  User_TLB_DDR_1_6   9302488      4096
# 392   Memory_Section_User_TLB_DDR_1_2_5  User_TLB_DDR_1_2   9021180      4096
# 547  Memory_Section_User_TLB_DDR_1_2_19  User_TLB_DDR_1_2   7012307      4096
# 518   Memory_Section_User_TLB_DDR_1_4_4  User_TLB_DDR_1_4   6492840      4096
# 706  Memory_Section_User_TLB_DDR_1_4_30  User_TLB_DDR_1_4   6439206      4096
# 375  Memory_Section_User_TLB_DDR_1_4_32  User_TLB_DDR_1_4   5939745      4096
# 276  Memory_Section_User_TLB_DDR_1_4_12  User_TLB_DDR_1_4   5490163      4096
# 155  Memory_Section_User_TLB_DDR_1_2_13  User_TLB_DDR_1_2   4371666      4096
# 7    Memory_Section_User_TLB_DDR_1_2_21  User_TLB_DDR_1_2   4240237      4096
# 467   Memory_Section_User_TLB_DDR_1_4_7  User_TLB_DDR_1_4   4040434      4096
# 673   Memory_Section_User_TLB_DDR_1_4_6  User_TLB_DDR_1_4   3915769      4096
# 349  Memory_Section_User_TLB_DDR_1_6_18  User_TLB_DDR_1_6   3754458      4096
# 482  Memory_Section_User_TLB_DDR_1_6_20  User_TLB_DDR_1_6   3394566      4096
# 1     Memory_Section_User_TLB_DDR_2_1_2  User_TLB_DDR_2_1   3149025      4096
# 885  Memory_Section_User_TLB_DDR_2_0_40  User_TLB_DDR_2_0   3124166      4096
# 510  Memory_Section_User_TLB_DDR_2_1_28  User_TLB_DDR_2_1   3119130      4096
# 24   Memory_Section_User_TLB_DDR_2_2_10  User_TLB_DDR_2_2   2918594      4096
# ..                                  ...               ...       ...       ...
# 520  Memory_Section_User_TLB_DDR_5_1_40  User_TLB_DDR_5_1      5751      4096
# 505   Memory_Section_User_TLB_DDR_5_2_7  User_TLB_DDR_5_2      4619      4096
# 858   Memory_Section_User_TLB_DDR_4_1_8  User_TLB_DDR_4_1      3510      4096
# 247  Memory_Section_User_TLB_DDR_5_1_18  User_TLB_DDR_5_1      2980      4096
# 821   Memory_Section_User_TLB_DDR_6_0_8  User_TLB_DDR_6_0      2857      4096
# 303  Memory_Section_User_TLB_DDR_6_0_28  User_TLB_DDR_6_0      2842      4096
# 683  Memory_Section_User_TLB_DDR_6_1_24  User_TLB_DDR_6_1      2647      4096
# 862  Memory_Section_User_TLB_DDR_6_4_39  User_TLB_DDR_6_4      2560      4096
# 230  Memory_Section_User_TLB_DDR_5_4_31  User_TLB_DDR_5_4      2558      4096
# 386  Memory_Section_User_TLB_DDR_6_4_19  User_TLB_DDR_6_4      2382      4096
# 757  Memory_Section_User_TLB_DDR_6_1_28  User_TLB_DDR_6_1      2236      4096
# 312   Memory_Section_User_TLB_DDR_5_1_2  User_TLB_DDR_5_1      2105      4096
# 64   Memory_Section_User_TLB_DDR_6_4_36  User_TLB_DDR_6_4      1791      4096
# 385  Memory_Section_User_TLB_DDR_6_0_27  User_TLB_DDR_6_0      1730      4096
# 454  Memory_Section_User_TLB_DDR_6_0_25  User_TLB_DDR_6_0      1504      4096
# 105   Memory_Section_User_TLB_DDR_6_4_3  User_TLB_DDR_6_4      1458      4096
# 422  Memory_Section_User_TLB_DDR_5_0_30  User_TLB_DDR_5_0      1444      4096
# 204  Memory_Section_User_TLB_DDR_5_0_13  User_TLB_DDR_5_0      1209      4096
# 782   Memory_Section_User_TLB_DDR_6_1_6  User_TLB_DDR_6_1      1209      4096
# 650  Memory_Section_User_TLB_DDR_5_2_10  User_TLB_DDR_5_2      1011      4096
# 112   Memory_Section_User_TLB_DDR_5_0_6  User_TLB_DDR_5_0       984      4096
# 760  Memory_Section_User_TLB_DDR_6_2_40  User_TLB_DDR_6_2       879      4096
# 815  Memory_Section_User_TLB_DDR_6_2_19  User_TLB_DDR_6_2       797      4096
# 609  Memory_Section_User_TLB_DDR_5_2_21  User_TLB_DDR_5_2       791      4096
# 93   Memory_Section_User_TLB_DDR_6_0_17  User_TLB_DDR_6_0       503      4096
# 187  Memory_Section_User_TLB_DDR_6_0_23  User_TLB_DDR_6_0       500      4096
# 280  Memory_Section_User_TLB_DDR_5_0_27  User_TLB_DDR_5_0       487      4096
# 231   Memory_Section_User_TLB_DDR_6_1_8  User_TLB_DDR_6_1       311      4096
# 578  Memory_Section_User_TLB_DDR_5_1_31  User_TLB_DDR_5_1       271      4096
# 169  Memory_Section_User_TLB_DDR_6_1_12  User_TLB_DDR_6_1        33      4096
#
#     Start Address
# 533             0
# 868      12931072
# 901      30000000
# 377      30c50000
# 817      3186f000
# 517             0
# 118        b23000
# 319       1645000
# 206      32440000
# 513      20c55000
# 807      32ed8000
# 462      216d5000
# 15       2208e000
# 414      338e3000
# 392      22a32000
# 547      232cd000
# 518      10c51000
# 706      11283000
# 375      118a8000
# 276      11e53000
# 155      2397d000
# 7        23da9000
# 467      12390000
# 673      1276b000
# 349      341c3000
# 482      34558000
# 1        44000000
# 885      40000000
# 510      44301000
# 24       48000000
# ..            ...
# 520      55040000
# 505      550c3000
# 858      54d28000
# 247      55042000
# 821      55110000
# 303      55111000
# 683      55100000
# 862      55120000
# 230      55012000
# 386      55121000
# 757      55101000
# 312      55043000
# 64       55122000
# 385      55112000
# 454      55113000
# 105      55123000
# 422      55086000
# 204      55087000
# 782      55102000
# 650      550c5000
# 112      55088000
# 760      55130000
# 815      55131000
# 609      550c6000
# 93       55114000
# 187      55115000
# 280      55089000
# 231      55103000
# 578      55044000
# 169      55104000
#
# [147 rows x 5 columns]
# 12931072 12912294
#                                    Name               TLB      Size Alignment  \
# 533   Memory_Section_User_TLB_DDR_1_2_9  User_TLB_DDR_1_2  12928576      4096
# 868  Memory_Section_User_TLB_DDR_1_4_23  User_TLB_DDR_1_4  12912294      4096
# 901  Memory_Section_User_TLB_DDR_1_6_33  User_TLB_DDR_1_6  12908347      4096
# 377  Memory_Section_User_TLB_DDR_1_6_16  User_TLB_DDR_1_6  12707935      4096
# 817  Memory_Section_User_TLB_DDR_1_6_24  User_TLB_DDR_1_6  12388929      4096
# 517   Memory_Section_User_TLB_DDR_1_1_2  User_TLB_DDR_1_1  11677145      4096
# 118  Memory_Section_User_TLB_DDR_1_1_12  User_TLB_DDR_1_1  11670948      4096
# 319  Memory_Section_User_TLB_DDR_1_1_11  User_TLB_DDR_1_1  11269710      4096
# 206  Memory_Section_User_TLB_DDR_1_6_23  User_TLB_DDR_1_6  11107380      4096
# 513   Memory_Section_User_TLB_DDR_1_2_7  User_TLB_DDR_1_2  11007727      4096
# 807   Memory_Section_User_TLB_DDR_1_6_5  User_TLB_DDR_1_6  10530661      4096
# 462  Memory_Section_User_TLB_DDR_1_2_37  User_TLB_DDR_1_2  10192400      4096
# 15   Memory_Section_User_TLB_DDR_1_2_10  User_TLB_DDR_1_2  10108804      4096
# 414  Memory_Section_User_TLB_DDR_1_6_39  User_TLB_DDR_1_6   9302488      4096
# 392   Memory_Section_User_TLB_DDR_1_2_5  User_TLB_DDR_1_2   9021180      4096
# 547  Memory_Section_User_TLB_DDR_1_2_19  User_TLB_DDR_1_2   7012307      4096
# 518   Memory_Section_User_TLB_DDR_1_4_4  User_TLB_DDR_1_4   6492840      4096
# 706  Memory_Section_User_TLB_DDR_1_4_30  User_TLB_DDR_1_4   6439206      4096
# 375  Memory_Section_User_TLB_DDR_1_4_32  User_TLB_DDR_1_4   5939745      4096
# 276  Memory_Section_User_TLB_DDR_1_4_12  User_TLB_DDR_1_4   5490163      4096
# 155  Memory_Section_User_TLB_DDR_1_2_13  User_TLB_DDR_1_2   4371666      4096
# 7    Memory_Section_User_TLB_DDR_1_2_21  User_TLB_DDR_1_2   4240237      4096
# 467   Memory_Section_User_TLB_DDR_1_4_7  User_TLB_DDR_1_4   4040434      4096
# 673   Memory_Section_User_TLB_DDR_1_4_6  User_TLB_DDR_1_4   3915769      4096
# 349  Memory_Section_User_TLB_DDR_1_6_18  User_TLB_DDR_1_6   3754458      4096
# 482  Memory_Section_User_TLB_DDR_1_6_20  User_TLB_DDR_1_6   3394566      4096
# 1     Memory_Section_User_TLB_DDR_2_1_2  User_TLB_DDR_2_1   3149025      4096
# 885  Memory_Section_User_TLB_DDR_2_0_40  User_TLB_DDR_2_0   3124166      4096
# 510  Memory_Section_User_TLB_DDR_2_1_28  User_TLB_DDR_2_1   3119130      4096
# 24   Memory_Section_User_TLB_DDR_2_2_10  User_TLB_DDR_2_2   2918594      4096
# ..                                  ...               ...       ...       ...
# 520  Memory_Section_User_TLB_DDR_5_1_40  User_TLB_DDR_5_1      5751      4096
# 505   Memory_Section_User_TLB_DDR_5_2_7  User_TLB_DDR_5_2      4619      4096
# 858   Memory_Section_User_TLB_DDR_4_1_8  User_TLB_DDR_4_1      3510      4096
# 247  Memory_Section_User_TLB_DDR_5_1_18  User_TLB_DDR_5_1      2980      4096
# 821   Memory_Section_User_TLB_DDR_6_0_8  User_TLB_DDR_6_0      2857      4096
# 303  Memory_Section_User_TLB_DDR_6_0_28  User_TLB_DDR_6_0      2842      4096
# 683  Memory_Section_User_TLB_DDR_6_1_24  User_TLB_DDR_6_1      2647      4096
# 862  Memory_Section_User_TLB_DDR_6_4_39  User_TLB_DDR_6_4      2560      4096
# 230  Memory_Section_User_TLB_DDR_5_4_31  User_TLB_DDR_5_4      2558      4096
# 386  Memory_Section_User_TLB_DDR_6_4_19  User_TLB_DDR_6_4      2382      4096
# 757  Memory_Section_User_TLB_DDR_6_1_28  User_TLB_DDR_6_1      2236      4096
# 312   Memory_Section_User_TLB_DDR_5_1_2  User_TLB_DDR_5_1      2105      4096
# 64   Memory_Section_User_TLB_DDR_6_4_36  User_TLB_DDR_6_4      1791      4096
# 385  Memory_Section_User_TLB_DDR_6_0_27  User_TLB_DDR_6_0      1730      4096
# 454  Memory_Section_User_TLB_DDR_6_0_25  User_TLB_DDR_6_0      1504      4096
# 105   Memory_Section_User_TLB_DDR_6_4_3  User_TLB_DDR_6_4      1458      4096
# 422  Memory_Section_User_TLB_DDR_5_0_30  User_TLB_DDR_5_0      1444      4096
# 204  Memory_Section_User_TLB_DDR_5_0_13  User_TLB_DDR_5_0      1209      4096
# 782   Memory_Section_User_TLB_DDR_6_1_6  User_TLB_DDR_6_1      1209      4096
# 650  Memory_Section_User_TLB_DDR_5_2_10  User_TLB_DDR_5_2      1011      4096
# 112   Memory_Section_User_TLB_DDR_5_0_6  User_TLB_DDR_5_0       984      4096
# 760  Memory_Section_User_TLB_DDR_6_2_40  User_TLB_DDR_6_2       879      4096
# 815  Memory_Section_User_TLB_DDR_6_2_19  User_TLB_DDR_6_2       797      4096
# 609  Memory_Section_User_TLB_DDR_5_2_21  User_TLB_DDR_5_2       791      4096
# 93   Memory_Section_User_TLB_DDR_6_0_17  User_TLB_DDR_6_0       503      4096
# 187  Memory_Section_User_TLB_DDR_6_0_23  User_TLB_DDR_6_0       500      4096
# 280  Memory_Section_User_TLB_DDR_5_0_27  User_TLB_DDR_5_0       487      4096
# 231   Memory_Section_User_TLB_DDR_6_1_8  User_TLB_DDR_6_1       311      4096
# 578  Memory_Section_User_TLB_DDR_5_1_31  User_TLB_DDR_5_1       271      4096
# 169  Memory_Section_User_TLB_DDR_6_1_12  User_TLB_DDR_6_1        33      4096
#
#     Start Address
# 533             0
# 868      12931072
# 901      25845760
# 377      30c50000
# 817      3186f000
# 517             0
# 118        b23000
# 319       1645000
# 206      32440000
# 513      20c55000
# 807      32ed8000
# 462      216d5000
# 15       2208e000
# 414      338e3000
# 392      22a32000
# 547      232cd000
# 518      10c51000
# 706      11283000
# 375      118a8000
# 276      11e53000
# 155      2397d000
# 7        23da9000
# 467      12390000
# 673      1276b000
# 349      341c3000
# 482      34558000
# 1        44000000
# 885      40000000
# 510      44301000
# 24       48000000
# ..            ...
# 520      55040000
# 505      550c3000
# 858      54d28000
# 247      55042000
# 821      55110000
# 303      55111000
# 683      55100000
# 862      55120000
# 230      55012000
# 386      55121000
# 757      55101000
# 312      55043000
# 64       55122000
# 385      55112000
# 454      55113000
# 105      55123000
# 422      55086000
# 204      55087000
# 782      55102000
# 650      550c5000
# 112      55088000
# 760      55130000
# 815      55131000
# 609      550c6000
# 93       55114000
# 187      55115000
# 280      55089000
# 231      55103000
# 578      55044000
# 169      55104000
#
# [147 rows x 5 columns]
# 25845760 12908347
#                                    Name               TLB      Size Alignment  \
# 533   Memory_Section_User_TLB_DDR_1_2_9  User_TLB_DDR_1_2  12928576      4096
# 868  Memory_Section_User_TLB_DDR_1_4_23  User_TLB_DDR_1_4  12912294      4096
# 901  Memory_Section_User_TLB_DDR_1_6_33  User_TLB_DDR_1_6  12908347      4096
# 377  Memory_Section_User_TLB_DDR_1_6_16  User_TLB_DDR_1_6  12707935      4096
# 817  Memory_Section_User_TLB_DDR_1_6_24  User_TLB_DDR_1_6  12388929      4096
# 517   Memory_Section_User_TLB_DDR_1_1_2  User_TLB_DDR_1_1  11677145      4096
# 118  Memory_Section_User_TLB_DDR_1_1_12  User_TLB_DDR_1_1  11670948      4096
# 319  Memory_Section_User_TLB_DDR_1_1_11  User_TLB_DDR_1_1  11269710      4096
# 206  Memory_Section_User_TLB_DDR_1_6_23  User_TLB_DDR_1_6  11107380      4096
# 513   Memory_Section_User_TLB_DDR_1_2_7  User_TLB_DDR_1_2  11007727      4096
# 807   Memory_Section_User_TLB_DDR_1_6_5  User_TLB_DDR_1_6  10530661      4096
# 462  Memory_Section_User_TLB_DDR_1_2_37  User_TLB_DDR_1_2  10192400      4096
# 15   Memory_Section_User_TLB_DDR_1_2_10  User_TLB_DDR_1_2  10108804      4096
# 414  Memory_Section_User_TLB_DDR_1_6_39  User_TLB_DDR_1_6   9302488      4096
# 392   Memory_Section_User_TLB_DDR_1_2_5  User_TLB_DDR_1_2   9021180      4096
# 547  Memory_Section_User_TLB_DDR_1_2_19  User_TLB_DDR_1_2   7012307      4096
# 518   Memory_Section_User_TLB_DDR_1_4_4  User_TLB_DDR_1_4   6492840      4096
# 706  Memory_Section_User_TLB_DDR_1_4_30  User_TLB_DDR_1_4   6439206      4096
# 375  Memory_Section_User_TLB_DDR_1_4_32  User_TLB_DDR_1_4   5939745      4096
# 276  Memory_Section_User_TLB_DDR_1_4_12  User_TLB_DDR_1_4   5490163      4096
# 155  Memory_Section_User_TLB_DDR_1_2_13  User_TLB_DDR_1_2   4371666      4096
# 7    Memory_Section_User_TLB_DDR_1_2_21  User_TLB_DDR_1_2   4240237      4096
# 467   Memory_Section_User_TLB_DDR_1_4_7  User_TLB_DDR_1_4   4040434      4096
# 673   Memory_Section_User_TLB_DDR_1_4_6  User_TLB_DDR_1_4   3915769      4096
# 349  Memory_Section_User_TLB_DDR_1_6_18  User_TLB_DDR_1_6   3754458      4096
# 482  Memory_Section_User_TLB_DDR_1_6_20  User_TLB_DDR_1_6   3394566      4096
# 1     Memory_Section_User_TLB_DDR_2_1_2  User_TLB_DDR_2_1   3149025      4096
# 885  Memory_Section_User_TLB_DDR_2_0_40  User_TLB_DDR_2_0   3124166      4096
# 510  Memory_Section_User_TLB_DDR_2_1_28  User_TLB_DDR_2_1   3119130      4096
# 24   Memory_Section_User_TLB_DDR_2_2_10  User_TLB_DDR_2_2   2918594      4096
# ..                                  ...               ...       ...       ...
# 520  Memory_Section_User_TLB_DDR_5_1_40  User_TLB_DDR_5_1      5751      4096
# 505   Memory_Section_User_TLB_DDR_5_2_7  User_TLB_DDR_5_2      4619      4096
# 858   Memory_Section_User_TLB_DDR_4_1_8  User_TLB_DDR_4_1      3510      4096
# 247  Memory_Section_User_TLB_DDR_5_1_18  User_TLB_DDR_5_1      2980      4096
# 821   Memory_Section_User_TLB_DDR_6_0_8  User_TLB_DDR_6_0      2857      4096
# 303  Memory_Section_User_TLB_DDR_6_0_28  User_TLB_DDR_6_0      2842      4096
# 683  Memory_Section_User_TLB_DDR_6_1_24  User_TLB_DDR_6_1      2647      4096
# 862  Memory_Section_User_TLB_DDR_6_4_39  User_TLB_DDR_6_4      2560      4096
# 230  Memory_Section_User_TLB_DDR_5_4_31  User_TLB_DDR_5_4      2558      4096
# 386  Memory_Section_User_TLB_DDR_6_4_19  User_TLB_DDR_6_4      2382      4096
# 757  Memory_Section_User_TLB_DDR_6_1_28  User_TLB_DDR_6_1      2236      4096
# 312   Memory_Section_User_TLB_DDR_5_1_2  User_TLB_DDR_5_1      2105      4096
# 64   Memory_Section_User_TLB_DDR_6_4_36  User_TLB_DDR_6_4      1791      4096
# 385  Memory_Section_User_TLB_DDR_6_0_27  User_TLB_DDR_6_0      1730      4096
# 454  Memory_Section_User_TLB_DDR_6_0_25  User_TLB_DDR_6_0      1504      4096
# 105   Memory_Section_User_TLB_DDR_6_4_3  User_TLB_DDR_6_4      1458      4096
# 422  Memory_Section_User_TLB_DDR_5_0_30  User_TLB_DDR_5_0      1444      4096
# 204  Memory_Section_User_TLB_DDR_5_0_13  User_TLB_DDR_5_0      1209      4096
# 782   Memory_Section_User_TLB_DDR_6_1_6  User_TLB_DDR_6_1      1209      4096
# 650  Memory_Section_User_TLB_DDR_5_2_10  User_TLB_DDR_5_2      1011      4096
# 112   Memory_Section_User_TLB_DDR_5_0_6  User_TLB_DDR_5_0       984      4096
# 760  Memory_Section_User_TLB_DDR_6_2_40  User_TLB_DDR_6_2       879      4096
# 815  Memory_Section_User_TLB_DDR_6_2_19  User_TLB_DDR_6_2       797      4096
# 609  Memory_Section_User_TLB_DDR_5_2_21  User_TLB_DDR_5_2       791      4096
# 93   Memory_Section_User_TLB_DDR_6_0_17  User_TLB_DDR_6_0       503      4096
# 187  Memory_Section_User_TLB_DDR_6_0_23  User_TLB_DDR_6_0       500      4096
# 280  Memory_Section_User_TLB_DDR_5_0_27  User_TLB_DDR_5_0       487      4096
# 231   Memory_Section_User_TLB_DDR_6_1_8  User_TLB_DDR_6_1       311      4096
# 578  Memory_Section_User_TLB_DDR_5_1_31  User_TLB_DDR_5_1       271      4096
# 169  Memory_Section_User_TLB_DDR_6_1_12  User_TLB_DDR_6_1        33      4096
#
#     Start Address
# 533             0
# 868      12931072
# 901      25845760
# 377      38756352
# 817      3186f000
# 517             0
# 118        b23000
# 319       1645000
# 206      32440000
# 513      20c55000
# 807      32ed8000
# 462      216d5000
# 15       2208e000
# 414      338e3000
# 392      22a32000
# 547      232cd000
# 518      10c51000
# 706      11283000
# 375      118a8000
# 276      11e53000
# 155      2397d000
# 7        23da9000
# 467      12390000
# 673      1276b000
# 349      341c3000
# 482      34558000
# 1        44000000
# 885      40000000
# 510      44301000
# 24       48000000
# ..            ...
# 520      55040000
# 505      550c3000
# 858      54d28000
# 247      55042000
# 821      55110000
# 303      55111000
# 683      55100000
# 862      55120000
# 230      55012000
# 386      55121000
# 757      55101000
# 312      55043000
# 64       55122000
# 385      55112000
# 454      55113000
# 105      55123000
# 422      55086000
# 204      55087000
# 782      55102000
# 650      550c5000
# 112      55088000
# 760      55130000
# 815      55131000
# 609      550c6000
# 93       55114000
# 187      55115000
# 280      55089000
# 231      55103000
# 578      55044000
# 169      55104000
#
# [147 rows x 5 columns]
# 38756352 12707935
#                                    Name               TLB      Size Alignment  \
# 533   Memory_Section_User_TLB_DDR_1_2_9  User_TLB_DDR_1_2  12928576      4096
# 868  Memory_Section_User_TLB_DDR_1_4_23  User_TLB_DDR_1_4  12912294      4096
# 901  Memory_Section_User_TLB_DDR_1_6_33  User_TLB_DDR_1_6  12908347      4096
# 377  Memory_Section_User_TLB_DDR_1_6_16  User_TLB_DDR_1_6  12707935      4096
# 817  Memory_Section_User_TLB_DDR_1_6_24  User_TLB_DDR_1_6  12388929      4096
# 517   Memory_Section_User_TLB_DDR_1_1_2  User_TLB_DDR_1_1  11677145      4096
# 118  Memory_Section_User_TLB_DDR_1_1_12  User_TLB_DDR_1_1  11670948      4096
# 319  Memory_Section_User_TLB_DDR_1_1_11  User_TLB_DDR_1_1  11269710      4096
# 206  Memory_Section_User_TLB_DDR_1_6_23  User_TLB_DDR_1_6  11107380      4096
# 513   Memory_Section_User_TLB_DDR_1_2_7  User_TLB_DDR_1_2  11007727      4096
# 807   Memory_Section_User_TLB_DDR_1_6_5  User_TLB_DDR_1_6  10530661      4096
# 462  Memory_Section_User_TLB_DDR_1_2_37  User_TLB_DDR_1_2  10192400      4096
# 15   Memory_Section_User_TLB_DDR_1_2_10  User_TLB_DDR_1_2  10108804      4096
# 414  Memory_Section_User_TLB_DDR_1_6_39  User_TLB_DDR_1_6   9302488      4096
# 392   Memory_Section_User_TLB_DDR_1_2_5  User_TLB_DDR_1_2   9021180      4096
# 547  Memory_Section_User_TLB_DDR_1_2_19  User_TLB_DDR_1_2   7012307      4096
# 518   Memory_Section_User_TLB_DDR_1_4_4  User_TLB_DDR_1_4   6492840      4096
# 706  Memory_Section_User_TLB_DDR_1_4_30  User_TLB_DDR_1_4   6439206      4096
# 375  Memory_Section_User_TLB_DDR_1_4_32  User_TLB_DDR_1_4   5939745      4096
# 276  Memory_Section_User_TLB_DDR_1_4_12  User_TLB_DDR_1_4   5490163      4096
# 155  Memory_Section_User_TLB_DDR_1_2_13  User_TLB_DDR_1_2   4371666      4096
# 7    Memory_Section_User_TLB_DDR_1_2_21  User_TLB_DDR_1_2   4240237      4096
# 467   Memory_Section_User_TLB_DDR_1_4_7  User_TLB_DDR_1_4   4040434      4096
# 673   Memory_Section_User_TLB_DDR_1_4_6  User_TLB_DDR_1_4   3915769      4096
# 349  Memory_Section_User_TLB_DDR_1_6_18  User_TLB_DDR_1_6   3754458      4096
# 482  Memory_Section_User_TLB_DDR_1_6_20  User_TLB_DDR_1_6   3394566      4096
# 1     Memory_Section_User_TLB_DDR_2_1_2  User_TLB_DDR_2_1   3149025      4096
# 885  Memory_Section_User_TLB_DDR_2_0_40  User_TLB_DDR_2_0   3124166      4096
# 510  Memory_Section_User_TLB_DDR_2_1_28  User_TLB_DDR_2_1   3119130      4096
# 24   Memory_Section_User_TLB_DDR_2_2_10  User_TLB_DDR_2_2   2918594      4096
# ..                                  ...               ...       ...       ...
# 520  Memory_Section_User_TLB_DDR_5_1_40  User_TLB_DDR_5_1      5751      4096
# 505   Memory_Section_User_TLB_DDR_5_2_7  User_TLB_DDR_5_2      4619      4096
# 858   Memory_Section_User_TLB_DDR_4_1_8  User_TLB_DDR_4_1      3510      4096
# 247  Memory_Section_User_TLB_DDR_5_1_18  User_TLB_DDR_5_1      2980      4096
# 821   Memory_Section_User_TLB_DDR_6_0_8  User_TLB_DDR_6_0      2857      4096
# 303  Memory_Section_User_TLB_DDR_6_0_28  User_TLB_DDR_6_0      2842      4096
# 683  Memory_Section_User_TLB_DDR_6_1_24  User_TLB_DDR_6_1      2647      4096
# 862  Memory_Section_User_TLB_DDR_6_4_39  User_TLB_DDR_6_4      2560      4096
# 230  Memory_Section_User_TLB_DDR_5_4_31  User_TLB_DDR_5_4      2558      4096
# 386  Memory_Section_User_TLB_DDR_6_4_19  User_TLB_DDR_6_4      2382      4096
# 757  Memory_Section_User_TLB_DDR_6_1_28  User_TLB_DDR_6_1      2236      4096
# 312   Memory_Section_User_TLB_DDR_5_1_2  User_TLB_DDR_5_1      2105      4096
# 64   Memory_Section_User_TLB_DDR_6_4_36  User_TLB_DDR_6_4      1791      4096
# 385  Memory_Section_User_TLB_DDR_6_0_27  User_TLB_DDR_6_0      1730      4096
# 454  Memory_Section_User_TLB_DDR_6_0_25  User_TLB_DDR_6_0      1504      4096
# 105   Memory_Section_User_TLB_DDR_6_4_3  User_TLB_DDR_6_4      1458      4096
# 422  Memory_Section_User_TLB_DDR_5_0_30  User_TLB_DDR_5_0      1444      4096
# 204  Memory_Section_User_TLB_DDR_5_0_13  User_TLB_DDR_5_0      1209      4096
# 782   Memory_Section_User_TLB_DDR_6_1_6  User_TLB_DDR_6_1      1209      4096
# 650  Memory_Section_User_TLB_DDR_5_2_10  User_TLB_DDR_5_2      1011      4096
# 112   Memory_Section_User_TLB_DDR_5_0_6  User_TLB_DDR_5_0       984      4096
# 760  Memory_Section_User_TLB_DDR_6_2_40  User_TLB_DDR_6_2       879      4096
# 815  Memory_Section_User_TLB_DDR_6_2_19  User_TLB_DDR_6_2       797      4096
# 609  Memory_Section_User_TLB_DDR_5_2_21  User_TLB_DDR_5_2       791      4096
# 93   Memory_Section_User_TLB_DDR_6_0_17  User_TLB_DDR_6_0       503      4096
# 187  Memory_Section_User_TLB_DDR_6_0_23  User_TLB_DDR_6_0       500      4096
# 280  Memory_Section_User_TLB_DDR_5_0_27  User_TLB_DDR_5_0       487      4096
# 231   Memory_Section_User_TLB_DDR_6_1_8  User_TLB_DDR_6_1       311      4096
# 578  Memory_Section_User_TLB_DDR_5_1_31  User_TLB_DDR_5_1       271      4096
# 169  Memory_Section_User_TLB_DDR_6_1_12  User_TLB_DDR_6_1        33      4096
#
#     Start Address
# 533             0
# 868      12931072
# 901      25845760
# 377      38756352
# 817      51466240
# 517             0
# 118        b23000
# 319       1645000
# 206      32440000
# 513      20c55000
# 807      32ed8000
# 462      216d5000
# 15       2208e000
# 414      338e3000
# 392      22a32000
# 547      232cd000
# 518      10c51000
# 706      11283000
# 375      118a8000
# 276      11e53000
# 155      2397d000
# 7        23da9000
# 467      12390000
# 673      1276b000
# 349      341c3000
# 482      34558000
# 1        44000000
# 885      40000000
# 510      44301000
# 24       48000000
# ..            ...
# 520      55040000
# 505      550c3000
# 858      54d28000
# 247      55042000
# 821      55110000
# 303      55111000
# 683      55100000
# 862      55120000
# 230      55012000
# 386      55121000
# 757      55101000
# 312      55043000
# 64       55122000
# 385      55112000
# 454      55113000
# 105      55123000
# 422      55086000
# 204      55087000
# 782      55102000
# 650      550c5000
# 112      55088000
# 760      55130000
# 815      55131000
# 609      550c6000
# 93       55114000
# 187      55115000
# 280      55089000
# 231      55103000
# 578      55044000
# 169      55104000
#
# [147 rows x 5 columns]
# 51466240 12388929
#                                    Name               TLB      Size Alignment  \
# 533   Memory_Section_User_TLB_DDR_1_2_9  User_TLB_DDR_1_2  12928576      4096
# 868  Memory_Section_User_TLB_DDR_1_4_23  User_TLB_DDR_1_4  12912294      4096
# 901  Memory_Section_User_TLB_DDR_1_6_33  User_TLB_DDR_1_6  12908347      4096
# 377  Memory_Section_User_TLB_DDR_1_6_16  User_TLB_DDR_1_6  12707935      4096
# 817  Memory_Section_User_TLB_DDR_1_6_24  User_TLB_DDR_1_6  12388929      4096
# 517   Memory_Section_User_TLB_DDR_1_1_2  User_TLB_DDR_1_1  11677145      4096
# 118  Memory_Section_User_TLB_DDR_1_1_12  User_TLB_DDR_1_1  11670948      4096
# 319  Memory_Section_User_TLB_DDR_1_1_11  User_TLB_DDR_1_1  11269710      4096
# 206  Memory_Section_User_TLB_DDR_1_6_23  User_TLB_DDR_1_6  11107380      4096
# 513   Memory_Section_User_TLB_DDR_1_2_7  User_TLB_DDR_1_2  11007727      4096
# 807   Memory_Section_User_TLB_DDR_1_6_5  User_TLB_DDR_1_6  10530661      4096
# 462  Memory_Section_User_TLB_DDR_1_2_37  User_TLB_DDR_1_2  10192400      4096
# 15   Memory_Section_User_TLB_DDR_1_2_10  User_TLB_DDR_1_2  10108804      4096
# 414  Memory_Section_User_TLB_DDR_1_6_39  User_TLB_DDR_1_6   9302488      4096
# 392   Memory_Section_User_TLB_DDR_1_2_5  User_TLB_DDR_1_2   9021180      4096
# 547  Memory_Section_User_TLB_DDR_1_2_19  User_TLB_DDR_1_2   7012307      4096
# 518   Memory_Section_User_TLB_DDR_1_4_4  User_TLB_DDR_1_4   6492840      4096
# 706  Memory_Section_User_TLB_DDR_1_4_30  User_TLB_DDR_1_4   6439206      4096
# 375  Memory_Section_User_TLB_DDR_1_4_32  User_TLB_DDR_1_4   5939745      4096
# 276  Memory_Section_User_TLB_DDR_1_4_12  User_TLB_DDR_1_4   5490163      4096
# 155  Memory_Section_User_TLB_DDR_1_2_13  User_TLB_DDR_1_2   4371666      4096
# 7    Memory_Section_User_TLB_DDR_1_2_21  User_TLB_DDR_1_2   4240237      4096
# 467   Memory_Section_User_TLB_DDR_1_4_7  User_TLB_DDR_1_4   4040434      4096
# 673   Memory_Section_User_TLB_DDR_1_4_6  User_TLB_DDR_1_4   3915769      4096
# 349  Memory_Section_User_TLB_DDR_1_6_18  User_TLB_DDR_1_6   3754458      4096
# 482  Memory_Section_User_TLB_DDR_1_6_20  User_TLB_DDR_1_6   3394566      4096
# 1     Memory_Section_User_TLB_DDR_2_1_2  User_TLB_DDR_2_1   3149025      4096
# 885  Memory_Section_User_TLB_DDR_2_0_40  User_TLB_DDR_2_0   3124166      4096
# 510  Memory_Section_User_TLB_DDR_2_1_28  User_TLB_DDR_2_1   3119130      4096
# 24   Memory_Section_User_TLB_DDR_2_2_10  User_TLB_DDR_2_2   2918594      4096
# ..                                  ...               ...       ...       ...
# 520  Memory_Section_User_TLB_DDR_5_1_40  User_TLB_DDR_5_1      5751      4096
# 505   Memory_Section_User_TLB_DDR_5_2_7  User_TLB_DDR_5_2      4619      4096
# 858   Memory_Section_User_TLB_DDR_4_1_8  User_TLB_DDR_4_1      3510      4096
# 247  Memory_Section_User_TLB_DDR_5_1_18  User_TLB_DDR_5_1      2980      4096
# 821   Memory_Section_User_TLB_DDR_6_0_8  User_TLB_DDR_6_0      2857      4096
# 303  Memory_Section_User_TLB_DDR_6_0_28  User_TLB_DDR_6_0      2842      4096
# 683  Memory_Section_User_TLB_DDR_6_1_24  User_TLB_DDR_6_1      2647      4096
# 862  Memory_Section_User_TLB_DDR_6_4_39  User_TLB_DDR_6_4      2560      4096
# 230  Memory_Section_User_TLB_DDR_5_4_31  User_TLB_DDR_5_4      2558      4096
# 386  Memory_Section_User_TLB_DDR_6_4_19  User_TLB_DDR_6_4      2382      4096
# 757  Memory_Section_User_TLB_DDR_6_1_28  User_TLB_DDR_6_1      2236      4096
# 312   Memory_Section_User_TLB_DDR_5_1_2  User_TLB_DDR_5_1      2105      4096
# 64   Memory_Section_User_TLB_DDR_6_4_36  User_TLB_DDR_6_4      1791      4096
# 385  Memory_Section_User_TLB_DDR_6_0_27  User_TLB_DDR_6_0      1730      4096
# 454  Memory_Section_User_TLB_DDR_6_0_25  User_TLB_DDR_6_0      1504      4096
# 105   Memory_Section_User_TLB_DDR_6_4_3  User_TLB_DDR_6_4      1458      4096
# 422  Memory_Section_User_TLB_DDR_5_0_30  User_TLB_DDR_5_0      1444      4096
# 204  Memory_Section_User_TLB_DDR_5_0_13  User_TLB_DDR_5_0      1209      4096
# 782   Memory_Section_User_TLB_DDR_6_1_6  User_TLB_DDR_6_1      1209      4096
# 650  Memory_Section_User_TLB_DDR_5_2_10  User_TLB_DDR_5_2      1011      4096
# 112   Memory_Section_User_TLB_DDR_5_0_6  User_TLB_DDR_5_0       984      4096
# 760  Memory_Section_User_TLB_DDR_6_2_40  User_TLB_DDR_6_2       879      4096
# 815  Memory_Section_User_TLB_DDR_6_2_19  User_TLB_DDR_6_2       797      4096
# 609  Memory_Section_User_TLB_DDR_5_2_21  User_TLB_DDR_5_2       791      4096
# 93   Memory_Section_User_TLB_DDR_6_0_17  User_TLB_DDR_6_0       503      4096
# 187  Memory_Section_User_TLB_DDR_6_0_23  User_TLB_DDR_6_0       500      4096
# 280  Memory_Section_User_TLB_DDR_5_0_27  User_TLB_DDR_5_0       487      4096
# 231   Memory_Section_User_TLB_DDR_6_1_8  User_TLB_DDR_6_1       311      4096
# 578  Memory_Section_User_TLB_DDR_5_1_31  User_TLB_DDR_5_1       271      4096
# 169  Memory_Section_User_TLB_DDR_6_1_12  User_TLB_DDR_6_1        33      4096
#
#     Start Address
# 533             0
# 868      12931072
# 901      25845760
# 377      38756352
# 817      51466240
# 517      63856640
# 118        b23000
# 319       1645000
# 206      32440000
# 513      20c55000
# 807      32ed8000
# 462      216d5000
# 15       2208e000
# 414      338e3000
# 392      22a32000
# 547      232cd000
# 518      10c51000
# 706      11283000
# 375      118a8000
# 276      11e53000
# 155      2397d000
# 7        23da9000
# 467      12390000
# 673      1276b000
# 349      341c3000
# 482      34558000
# 1        44000000
# 885      40000000
# 510      44301000
# 24       48000000
# ..            ...
# 520      55040000
# 505      550c3000
# 858      54d28000
# 247      55042000
# 821      55110000
# 303      55111000
# 683      55100000
# 862      55120000
# 230      55012000
# 386      55121000
# 757      55101000
# 312      55043000
# 64       55122000
# 385      55112000
# 454      55113000
# 105      55123000
# 422      55086000
# 204      55087000
# 782      55102000
# 650      550c5000
# 112      55088000
# 760      55130000
# 815      55131000
# 609      550c6000
# 93       55114000
# 187      55115000
# 280      55089000
# 231      55103000
# 578      55044000
# 169      55104000
#
# [147 rows x 5 columns]
# 63856640 11677145
#                                    Name               TLB      Size Alignment  \
# 533   Memory_Section_User_TLB_DDR_1_2_9  User_TLB_DDR_1_2  12928576      4096
# 868  Memory_Section_User_TLB_DDR_1_4_23  User_TLB_DDR_1_4  12912294      4096
# 901  Memory_Section_User_TLB_DDR_1_6_33  User_TLB_DDR_1_6  12908347      4096
# 377  Memory_Section_User_TLB_DDR_1_6_16  User_TLB_DDR_1_6  12707935      4096
# 817  Memory_Section_User_TLB_DDR_1_6_24  User_TLB_DDR_1_6  12388929      4096
# 517   Memory_Section_User_TLB_DDR_1_1_2  User_TLB_DDR_1_1  11677145      4096
# 118  Memory_Section_User_TLB_DDR_1_1_12  User_TLB_DDR_1_1  11670948      4096
# 319  Memory_Section_User_TLB_DDR_1_1_11  User_TLB_DDR_1_1  11269710      4096
# 206  Memory_Section_User_TLB_DDR_1_6_23  User_TLB_DDR_1_6  11107380      4096
# 513   Memory_Section_User_TLB_DDR_1_2_7  User_TLB_DDR_1_2  11007727      4096
# 807   Memory_Section_User_TLB_DDR_1_6_5  User_TLB_DDR_1_6  10530661      4096
# 462  Memory_Section_User_TLB_DDR_1_2_37  User_TLB_DDR_1_2  10192400      4096
# 15   Memory_Section_User_TLB_DDR_1_2_10  User_TLB_DDR_1_2  10108804      4096
# 414  Memory_Section_User_TLB_DDR_1_6_39  User_TLB_DDR_1_6   9302488      4096
# 392   Memory_Section_User_TLB_DDR_1_2_5  User_TLB_DDR_1_2   9021180      4096
# 547  Memory_Section_User_TLB_DDR_1_2_19  User_TLB_DDR_1_2   7012307      4096
# 518   Memory_Section_User_TLB_DDR_1_4_4  User_TLB_DDR_1_4   6492840      4096
# 706  Memory_Section_User_TLB_DDR_1_4_30  User_TLB_DDR_1_4   6439206      4096
# 375  Memory_Section_User_TLB_DDR_1_4_32  User_TLB_DDR_1_4   5939745      4096
# 276  Memory_Section_User_TLB_DDR_1_4_12  User_TLB_DDR_1_4   5490163      4096
# 155  Memory_Section_User_TLB_DDR_1_2_13  User_TLB_DDR_1_2   4371666      4096
# 7    Memory_Section_User_TLB_DDR_1_2_21  User_TLB_DDR_1_2   4240237      4096
# 467   Memory_Section_User_TLB_DDR_1_4_7  User_TLB_DDR_1_4   4040434      4096
# 673   Memory_Section_User_TLB_DDR_1_4_6  User_TLB_DDR_1_4   3915769      4096
# 349  Memory_Section_User_TLB_DDR_1_6_18  User_TLB_DDR_1_6   3754458      4096
# 482  Memory_Section_User_TLB_DDR_1_6_20  User_TLB_DDR_1_6   3394566      4096
# 1     Memory_Section_User_TLB_DDR_2_1_2  User_TLB_DDR_2_1   3149025      4096
# 885  Memory_Section_User_TLB_DDR_2_0_40  User_TLB_DDR_2_0   3124166      4096
# 510  Memory_Section_User_TLB_DDR_2_1_28  User_TLB_DDR_2_1   3119130      4096
# 24   Memory_Section_User_TLB_DDR_2_2_10  User_TLB_DDR_2_2   2918594      4096
# ..                                  ...               ...       ...       ...
# 520  Memory_Section_User_TLB_DDR_5_1_40  User_TLB_DDR_5_1      5751      4096
# 505   Memory_Section_User_TLB_DDR_5_2_7  User_TLB_DDR_5_2      4619      4096
# 858   Memory_Section_User_TLB_DDR_4_1_8  User_TLB_DDR_4_1      3510      4096
# 247  Memory_Section_User_TLB_DDR_5_1_18  User_TLB_DDR_5_1      2980      4096
# 821   Memory_Section_User_TLB_DDR_6_0_8  User_TLB_DDR_6_0      2857      4096
# 303  Memory_Section_User_TLB_DDR_6_0_28  User_TLB_DDR_6_0      2842      4096
# 683  Memory_Section_User_TLB_DDR_6_1_24  User_TLB_DDR_6_1      2647      4096
# 862  Memory_Section_User_TLB_DDR_6_4_39  User_TLB_DDR_6_4      2560      4096
# 230  Memory_Section_User_TLB_DDR_5_4_31  User_TLB_DDR_5_4      2558      4096
# 386  Memory_Section_User_TLB_DDR_6_4_19  User_TLB_DDR_6_4      2382      4096
# 757  Memory_Section_User_TLB_DDR_6_1_28  User_TLB_DDR_6_1      2236      4096
# 312   Memory_Section_User_TLB_DDR_5_1_2  User_TLB_DDR_5_1      2105      4096
# 64   Memory_Section_User_TLB_DDR_6_4_36  User_TLB_DDR_6_4      1791      4096
# 385  Memory_Section_User_TLB_DDR_6_0_27  User_TLB_DDR_6_0      1730      4096
# 454  Memory_Section_User_TLB_DDR_6_0_25  User_TLB_DDR_6_0      1504      4096
# 105   Memory_Section_User_TLB_DDR_6_4_3  User_TLB_DDR_6_4      1458      4096
# ...
# 821   Memory_Section_User_TLB_DDR_6_0_8  User_TLB_DDR_6_0      2857      4096
# 303  Memory_Section_User_TLB_DDR_6_0_28  User_TLB_DDR_6_0      2842      4096
# 683  Memory_Section_User_TLB_DDR_6_1_24  User_TLB_DDR_6_1      2647      4096
# 862  Memory_Section_User_TLB_DDR_6_4_39  User_TLB_DDR_6_4      2560      4096
# 230  Memory_Section_User_TLB_DDR_5_4_31  User_TLB_DDR_5_4      2558      4096
# 386  Memory_Section_User_TLB_DDR_6_4_19  User_TLB_DDR_6_4      2382      4096
# 757  Memory_Section_User_TLB_DDR_6_1_28  User_TLB_DDR_6_1      2236      4096
# 312   Memory_Section_User_TLB_DDR_5_1_2  User_TLB_DDR_5_1      2105      4096
# 64   Memory_Section_User_TLB_DDR_6_4_36  User_TLB_DDR_6_4      1791      4096
# 385  Memory_Section_User_TLB_DDR_6_0_27  User_TLB_DDR_6_0      1730      4096
# 454  Memory_Section_User_TLB_DDR_6_0_25  User_TLB_DDR_6_0      1504      4096
# 105   Memory_Section_User_TLB_DDR_6_4_3  User_TLB_DDR_6_4      1458      4096
# 422  Memory_Section_User_TLB_DDR_5_0_30  User_TLB_DDR_5_0      1444      4096
# 204  Memory_Section_User_TLB_DDR_5_0_13  User_TLB_DDR_5_0      1209      4096
# 782   Memory_Section_User_TLB_DDR_6_1_6  User_TLB_DDR_6_1      1209      4096
# 650  Memory_Section_User_TLB_DDR_5_2_10  User_TLB_DDR_5_2      1011      4096
# 112   Memory_Section_User_TLB_DDR_5_0_6  User_TLB_DDR_5_0       984      4096
# 760  Memory_Section_User_TLB_DDR_6_2_40  User_TLB_DDR_6_2       879      4096
# 815  Memory_Section_User_TLB_DDR_6_2_19  User_TLB_DDR_6_2       797      4096
# 609  Memory_Section_User_TLB_DDR_5_2_21  User_TLB_DDR_5_2       791      4096
# 93   Memory_Section_User_TLB_DDR_6_0_17  User_TLB_DDR_6_0       503      4096
# 187  Memory_Section_User_TLB_DDR_6_0_23  User_TLB_DDR_6_0       500      4096
# 280  Memory_Section_User_TLB_DDR_5_0_27  User_TLB_DDR_5_0       487      4096
# 231   Memory_Section_User_TLB_DDR_6_1_8  User_TLB_DDR_6_1       311      4096
# 578  Memory_Section_User_TLB_DDR_5_1_31  User_TLB_DDR_5_1       271      4096
# 169  Memory_Section_User_TLB_DDR_6_1_12  User_TLB_DDR_6_1        33      4096
#
#     Start Address
# 533             0
# 868      12931072
# 901      25845760
# 377      38756352
# 817      51466240
# 517      63856640
# 118      75534336
# 319      87207936
# 206      98480128
# 513     109588480
# 807     120598528
# 462     131129344
# 15      141324288
# 414     151433216
# 392     160739328
# 547     169762816
# 518     176775168
# 706     183271424
# 375     189714432
# 276     195657728
# 155     201150464
# 7       205524992
# 467     209768448
# 673     213811200
# 349     217726976
# 482     221483008
# 1       224878592
# 885     228028416
# 510     231153664
# 24      234274816
# ..            ...
# 520     288399360
# 505     288407552
# 858     288415744
# 247     288419840
# 821     288423936
# 303     288428032
# 683     288432128
# 862     288436224
# 230     288440320
# 386     288444416
# 757     288448512
# 312     288452608
# 64      288456704
# 385     288460800
# 454     288464896
# 105     288468992
# 422     288473088
# 204     288477184
# 782     288481280
# 650     288485376
# 112     288489472
# 760     288493568
# 815     288497664
# 609     288501760
# 93      288505856
# 187     288509952
# 280     288514048
# 231      55103000
# 578      55044000
# 169      55104000
#
# [147 rows x 5 columns]
# 288514048 487
#                                    Name               TLB      Size Alignment  \
# 533   Memory_Section_User_TLB_DDR_1_2_9  User_TLB_DDR_1_2  12928576      4096
# 868  Memory_Section_User_TLB_DDR_1_4_23  User_TLB_DDR_1_4  12912294      4096
# 901  Memory_Section_User_TLB_DDR_1_6_33  User_TLB_DDR_1_6  12908347      4096
# 377  Memory_Section_User_TLB_DDR_1_6_16  User_TLB_DDR_1_6  12707935      4096
# 817  Memory_Section_User_TLB_DDR_1_6_24  User_TLB_DDR_1_6  12388929      4096
# 517   Memory_Section_User_TLB_DDR_1_1_2  User_TLB_DDR_1_1  11677145      4096
# 118  Memory_Section_User_TLB_DDR_1_1_12  User_TLB_DDR_1_1  11670948      4096
# 319  Memory_Section_User_TLB_DDR_1_1_11  User_TLB_DDR_1_1  11269710      4096
# 206  Memory_Section_User_TLB_DDR_1_6_23  User_TLB_DDR_1_6  11107380      4096
# 513   Memory_Section_User_TLB_DDR_1_2_7  User_TLB_DDR_1_2  11007727      4096
# 807   Memory_Section_User_TLB_DDR_1_6_5  User_TLB_DDR_1_6  10530661      4096
# 462  Memory_Section_User_TLB_DDR_1_2_37  User_TLB_DDR_1_2  10192400      4096
# 15   Memory_Section_User_TLB_DDR_1_2_10  User_TLB_DDR_1_2  10108804      4096
# 414  Memory_Section_User_TLB_DDR_1_6_39  User_TLB_DDR_1_6   9302488      4096
# 392   Memory_Section_User_TLB_DDR_1_2_5  User_TLB_DDR_1_2   9021180      4096
# 547  Memory_Section_User_TLB_DDR_1_2_19  User_TLB_DDR_1_2   7012307      4096
# 518   Memory_Section_User_TLB_DDR_1_4_4  User_TLB_DDR_1_4   6492840      4096
# 706  Memory_Section_User_TLB_DDR_1_4_30  User_TLB_DDR_1_4   6439206      4096
# 375  Memory_Section_User_TLB_DDR_1_4_32  User_TLB_DDR_1_4   5939745      4096
# 276  Memory_Section_User_TLB_DDR_1_4_12  User_TLB_DDR_1_4   5490163      4096
# 155  Memory_Section_User_TLB_DDR_1_2_13  User_TLB_DDR_1_2   4371666      4096
# 7    Memory_Section_User_TLB_DDR_1_2_21  User_TLB_DDR_1_2   4240237      4096
# 467   Memory_Section_User_TLB_DDR_1_4_7  User_TLB_DDR_1_4   4040434      4096
# 673   Memory_Section_User_TLB_DDR_1_4_6  User_TLB_DDR_1_4   3915769      4096
# 349  Memory_Section_User_TLB_DDR_1_6_18  User_TLB_DDR_1_6   3754458      4096
# 482  Memory_Section_User_TLB_DDR_1_6_20  User_TLB_DDR_1_6   3394566      4096
# 1     Memory_Section_User_TLB_DDR_2_1_2  User_TLB_DDR_2_1   3149025      4096
# 885  Memory_Section_User_TLB_DDR_2_0_40  User_TLB_DDR_2_0   3124166      4096
# 510  Memory_Section_User_TLB_DDR_2_1_28  User_TLB_DDR_2_1   3119130      4096
# 24   Memory_Section_User_TLB_DDR_2_2_10  User_TLB_DDR_2_2   2918594      4096
# ..                                  ...               ...       ...       ...
# 520  Memory_Section_User_TLB_DDR_5_1_40  User_TLB_DDR_5_1      5751      4096
# 505   Memory_Section_User_TLB_DDR_5_2_7  User_TLB_DDR_5_2      4619      4096
# 858   Memory_Section_User_TLB_DDR_4_1_8  User_TLB_DDR_4_1      3510      4096
# 247  Memory_Section_User_TLB_DDR_5_1_18  User_TLB_DDR_5_1      2980      4096
# 821   Memory_Section_User_TLB_DDR_6_0_8  User_TLB_DDR_6_0      2857      4096
# 303  Memory_Section_User_TLB_DDR_6_0_28  User_TLB_DDR_6_0      2842      4096
# 683  Memory_Section_User_TLB_DDR_6_1_24  User_TLB_DDR_6_1      2647      4096
# 862  Memory_Section_User_TLB_DDR_6_4_39  User_TLB_DDR_6_4      2560      4096
# 230  Memory_Section_User_TLB_DDR_5_4_31  User_TLB_DDR_5_4      2558      4096
# 386  Memory_Section_User_TLB_DDR_6_4_19  User_TLB_DDR_6_4      2382      4096
# 757  Memory_Section_User_TLB_DDR_6_1_28  User_TLB_DDR_6_1      2236      4096
# 312   Memory_Section_User_TLB_DDR_5_1_2  User_TLB_DDR_5_1      2105      4096
# 64   Memory_Section_User_TLB_DDR_6_4_36  User_TLB_DDR_6_4      1791      4096
# 385  Memory_Section_User_TLB_DDR_6_0_27  User_TLB_DDR_6_0      1730      4096
# 454  Memory_Section_User_TLB_DDR_6_0_25  User_TLB_DDR_6_0      1504      4096
# 105   Memory_Section_User_TLB_DDR_6_4_3  User_TLB_DDR_6_4      1458      4096
# 422  Memory_Section_User_TLB_DDR_5_0_30  User_TLB_DDR_5_0      1444      4096
# 204  Memory_Section_User_TLB_DDR_5_0_13  User_TLB_DDR_5_0      1209      4096
# 782   Memory_Section_User_TLB_DDR_6_1_6  User_TLB_DDR_6_1      1209      4096
# 650  Memory_Section_User_TLB_DDR_5_2_10  User_TLB_DDR_5_2      1011      4096
# 112   Memory_Section_User_TLB_DDR_5_0_6  User_TLB_DDR_5_0       984      4096
# 760  Memory_Section_User_TLB_DDR_6_2_40  User_TLB_DDR_6_2       879      4096
# 815  Memory_Section_User_TLB_DDR_6_2_19  User_TLB_DDR_6_2       797      4096
# 609  Memory_Section_User_TLB_DDR_5_2_21  User_TLB_DDR_5_2       791      4096
# 93   Memory_Section_User_TLB_DDR_6_0_17  User_TLB_DDR_6_0       503      4096
# 187  Memory_Section_User_TLB_DDR_6_0_23  User_TLB_DDR_6_0       500      4096
# 280  Memory_Section_User_TLB_DDR_5_0_27  User_TLB_DDR_5_0       487      4096
# 231   Memory_Section_User_TLB_DDR_6_1_8  User_TLB_DDR_6_1       311      4096
# 578  Memory_Section_User_TLB_DDR_5_1_31  User_TLB_DDR_5_1       271      4096
# 169  Memory_Section_User_TLB_DDR_6_1_12  User_TLB_DDR_6_1        33      4096
#
#     Start Address
# 533             0
# 868      12931072
# 901      25845760
# 377      38756352
# 817      51466240
# 517      63856640
# 118      75534336
# 319      87207936
# 206      98480128
# 513     109588480
# 807     120598528
# 462     131129344
# 15      141324288
# 414     151433216
# 392     160739328
# 547     169762816
# 518     176775168
# 706     183271424
# 375     189714432
# 276     195657728
# 155     201150464
# 7       205524992
# 467     209768448
# 673     213811200
# 349     217726976
# 482     221483008
# 1       224878592
# 885     228028416
# 510     231153664
# 24      234274816
# ..            ...
# 520     288399360
# 505     288407552
# 858     288415744
# 247     288419840
# 821     288423936
# 303     288428032
# 683     288432128
# 862     288436224
# 230     288440320
# 386     288444416
# 757     288448512
# 312     288452608
# 64      288456704
# 385     288460800
# 454     288464896
# 105     288468992
# 422     288473088
# 204     288477184
# 782     288481280
# 650     288485376
# 112     288489472
# 760     288493568
# 815     288497664
# 609     288501760
# 93      288505856
# 187     288509952
# 280     288514048
# 231     288518144
# 578      55044000
# 169      55104000
#
# [147 rows x 5 columns]
# 288518144 311
#                                    Name               TLB      Size Alignment  \
# 533   Memory_Section_User_TLB_DDR_1_2_9  User_TLB_DDR_1_2  12928576      4096
# 868  Memory_Section_User_TLB_DDR_1_4_23  User_TLB_DDR_1_4  12912294      4096
# 901  Memory_Section_User_TLB_DDR_1_6_33  User_TLB_DDR_1_6  12908347      4096
# 377  Memory_Section_User_TLB_DDR_1_6_16  User_TLB_DDR_1_6  12707935      4096
# 817  Memory_Section_User_TLB_DDR_1_6_24  User_TLB_DDR_1_6  12388929      4096
# 517   Memory_Section_User_TLB_DDR_1_1_2  User_TLB_DDR_1_1  11677145      4096
# 118  Memory_Section_User_TLB_DDR_1_1_12  User_TLB_DDR_1_1  11670948      4096
# 319  Memory_Section_User_TLB_DDR_1_1_11  User_TLB_DDR_1_1  11269710      4096
# 206  Memory_Section_User_TLB_DDR_1_6_23  User_TLB_DDR_1_6  11107380      4096
# 513   Memory_Section_User_TLB_DDR_1_2_7  User_TLB_DDR_1_2  11007727      4096
# 807   Memory_Section_User_TLB_DDR_1_6_5  User_TLB_DDR_1_6  10530661      4096
# 462  Memory_Section_User_TLB_DDR_1_2_37  User_TLB_DDR_1_2  10192400      4096
# 15   Memory_Section_User_TLB_DDR_1_2_10  User_TLB_DDR_1_2  10108804      4096
# 414  Memory_Section_User_TLB_DDR_1_6_39  User_TLB_DDR_1_6   9302488      4096
# 392   Memory_Section_User_TLB_DDR_1_2_5  User_TLB_DDR_1_2   9021180      4096
# 547  Memory_Section_User_TLB_DDR_1_2_19  User_TLB_DDR_1_2   7012307      4096
# 518   Memory_Section_User_TLB_DDR_1_4_4  User_TLB_DDR_1_4   6492840      4096
# 706  Memory_Section_User_TLB_DDR_1_4_30  User_TLB_DDR_1_4   6439206      4096
# 375  Memory_Section_User_TLB_DDR_1_4_32  User_TLB_DDR_1_4   5939745      4096
# 276  Memory_Section_User_TLB_DDR_1_4_12  User_TLB_DDR_1_4   5490163      4096
# 155  Memory_Section_User_TLB_DDR_1_2_13  User_TLB_DDR_1_2   4371666      4096
# 7    Memory_Section_User_TLB_DDR_1_2_21  User_TLB_DDR_1_2   4240237      4096
# 467   Memory_Section_User_TLB_DDR_1_4_7  User_TLB_DDR_1_4   4040434      4096
# 673   Memory_Section_User_TLB_DDR_1_4_6  User_TLB_DDR_1_4   3915769      4096
# 349  Memory_Section_User_TLB_DDR_1_6_18  User_TLB_DDR_1_6   3754458      4096
# 482  Memory_Section_User_TLB_DDR_1_6_20  User_TLB_DDR_1_6   3394566      4096
# 1     Memory_Section_User_TLB_DDR_2_1_2  User_TLB_DDR_2_1   3149025      4096
# 885  Memory_Section_User_TLB_DDR_2_0_40  User_TLB_DDR_2_0   3124166      4096
# 510  Memory_Section_User_TLB_DDR_2_1_28  User_TLB_DDR_2_1   3119130      4096
# 24   Memory_Section_User_TLB_DDR_2_2_10  User_TLB_DDR_2_2   2918594      4096
# ..                                  ...               ...       ...       ...
# 520  Memory_Section_User_TLB_DDR_5_1_40  User_TLB_DDR_5_1      5751      4096
# 505   Memory_Section_User_TLB_DDR_5_2_7  User_TLB_DDR_5_2      4619      4096
# 858   Memory_Section_User_TLB_DDR_4_1_8  User_TLB_DDR_4_1      3510      4096
# 247  Memory_Section_User_TLB_DDR_5_1_18  User_TLB_DDR_5_1      2980      4096
# 821   Memory_Section_User_TLB_DDR_6_0_8  User_TLB_DDR_6_0      2857      4096
# 303  Memory_Section_User_TLB_DDR_6_0_28  User_TLB_DDR_6_0      2842      4096
# 683  Memory_Section_User_TLB_DDR_6_1_24  User_TLB_DDR_6_1      2647      4096
# 862  Memory_Section_User_TLB_DDR_6_4_39  User_TLB_DDR_6_4      2560      4096
# 230  Memory_Section_User_TLB_DDR_5_4_31  User_TLB_DDR_5_4      2558      4096
# 386  Memory_Section_User_TLB_DDR_6_4_19  User_TLB_DDR_6_4      2382      4096
# 757  Memory_Section_User_TLB_DDR_6_1_28  User_TLB_DDR_6_1      2236      4096
# 312   Memory_Section_User_TLB_DDR_5_1_2  User_TLB_DDR_5_1      2105      4096
# 64   Memory_Section_User_TLB_DDR_6_4_36  User_TLB_DDR_6_4      1791      4096
# 385  Memory_Section_User_TLB_DDR_6_0_27  User_TLB_DDR_6_0      1730      4096
# 454  Memory_Section_User_TLB_DDR_6_0_25  User_TLB_DDR_6_0      1504      4096
# 105   Memory_Section_User_TLB_DDR_6_4_3  User_TLB_DDR_6_4      1458      4096
# 422  Memory_Section_User_TLB_DDR_5_0_30  User_TLB_DDR_5_0      1444      4096
# 204  Memory_Section_User_TLB_DDR_5_0_13  User_TLB_DDR_5_0      1209      4096
# 782   Memory_Section_User_TLB_DDR_6_1_6  User_TLB_DDR_6_1      1209      4096
# 650  Memory_Section_User_TLB_DDR_5_2_10  User_TLB_DDR_5_2      1011      4096
# 112   Memory_Section_User_TLB_DDR_5_0_6  User_TLB_DDR_5_0       984      4096
# 760  Memory_Section_User_TLB_DDR_6_2_40  User_TLB_DDR_6_2       879      4096
# 815  Memory_Section_User_TLB_DDR_6_2_19  User_TLB_DDR_6_2       797      4096
# 609  Memory_Section_User_TLB_DDR_5_2_21  User_TLB_DDR_5_2       791      4096
# 93   Memory_Section_User_TLB_DDR_6_0_17  User_TLB_DDR_6_0       503      4096
# 187  Memory_Section_User_TLB_DDR_6_0_23  User_TLB_DDR_6_0       500      4096
# 280  Memory_Section_User_TLB_DDR_5_0_27  User_TLB_DDR_5_0       487      4096
# 231   Memory_Section_User_TLB_DDR_6_1_8  User_TLB_DDR_6_1       311      4096
# 578  Memory_Section_User_TLB_DDR_5_1_31  User_TLB_DDR_5_1       271      4096
# 169  Memory_Section_User_TLB_DDR_6_1_12  User_TLB_DDR_6_1        33      4096
#
#     Start Address
# 533             0
# 868      12931072
# 901      25845760
# 377      38756352
# 817      51466240
# 517      63856640
# 118      75534336
# 319      87207936
# 206      98480128
# 513     109588480
# 807     120598528
# 462     131129344
# 15      141324288
# 414     151433216
# 392     160739328
# 547     169762816
# 518     176775168
# 706     183271424
# 375     189714432
# 276     195657728
# 155     201150464
# 7       205524992
# 467     209768448
# 673     213811200
# 349     217726976
# 482     221483008
# 1       224878592
# 885     228028416
# 510     231153664
# 24      234274816
# ..            ...
# 520     288399360
# 505     288407552
# 858     288415744
# 247     288419840
# 821     288423936
# 303     288428032
# 683     288432128
# 862     288436224
# 230     288440320
# 386     288444416
# 757     288448512
# 312     288452608
# 64      288456704
# 385     288460800
# 454     288464896
# 105     288468992
# 422     288473088
# 204     288477184
# 782     288481280
# 650     288485376
# 112     288489472
# 760     288493568
# 815     288497664
# 609     288501760
# 93      288505856
# 187     288509952
# 280     288514048
# 231     288518144
# 578     288522240
# 169      55104000
#
# [147 rows x 5 columns]
# 288522240 271

# %%
runtime = 0
tlb_average = pd.DataFrame()
memory_average = pd.DataFrame()
tlb_memlist = []
tlb_average, memory_average, tlb_memlist =  getData_average()

b, runtime = runMergeSort(memory_average)
# Out:
#                 Name  TLB  Size  Alignment Start Address     Min Size  \
# 8   User_TLB_DDR_1_1  NaN   NaN        NaN             0  234109656.0
# 11  User_TLB_DDR_1_4  NaN   NaN        NaN     268435456  221239593.0
# 4   User_TLB_DDR_1_2  NaN   NaN        NaN     536870912  213966068.0
# 0   User_TLB_DDR_1_6  NaN   NaN        NaN     805306368  130464993.0
# 7   User_TLB_DDR_2_0  NaN   NaN        NaN    1073741824   55660258.0
# 23  User_TLB_DDR_2_1  NaN   NaN        NaN    1140850688   30086856.0
# 9   User_TLB_DDR_2_2  NaN   NaN        NaN    1207959552   22763020.0
# 14  User_TLB_DDR_2_4  NaN   NaN        NaN    1275068416   18718225.0
# 19  User_TLB_DDR_3_3  NaN   NaN        NaN    1342177280   14798201.0
# 22  User_TLB_DDR_3_1  NaN   NaN        NaN    1358954496   13082132.0
# 5   User_TLB_DDR_3_0  NaN   NaN        NaN    1375731712   10691621.0
# 10  User_TLB_DDR_3_2  NaN   NaN        NaN    1392508928    4956311.0
# 16  User_TLB_DDR_4_3  NaN   NaN        NaN    1409286144    3876510.0
# 20  User_TLB_DDR_4_2  NaN   NaN        NaN    1413480448    3828590.0
# 1   User_TLB_DDR_4_0  NaN   NaN        NaN    1417674752    3098236.0
# 12  User_TLB_DDR_4_1  NaN   NaN        NaN    1421869056    1273536.0
# 3   User_TLB_DDR_5_4  NaN   NaN        NaN    1426063360     220272.0
# 18  User_TLB_DDR_5_1  NaN   NaN        NaN    1426325504     199684.0
# 2   User_TLB_DDR_5_0  NaN   NaN        NaN    1426587648     131454.0
# 6   User_TLB_DDR_5_2  NaN   NaN        NaN    1426849792     123267.0
# 15  User_TLB_DDR_6_1  NaN   NaN        NaN    1427111936      64271.0
# 17  User_TLB_DDR_6_0  NaN   NaN        NaN    1427177472      57550.0
# 13  User_TLB_DDR_6_4  NaN   NaN        NaN    1427243008      53057.0
# 21  User_TLB_DDR_6_2  NaN   NaN        NaN    1427308544      37951.0
#
#     Size In KB
# 8     262144.0
# 11    262144.0
# 4     262144.0
# 0     262144.0
# 7      65536.0
# 23     65536.0
# 9      65536.0
# 14     65536.0
# 19     16384.0
# 22     16384.0
# 5      16384.0
# 10     16384.0
# 16      4096.0
# 20      4096.0
# 1       4096.0
# 12      4096.0
# 3        256.0
# 18       256.0
# 2        256.0
# 6        256.0
# 15        64.0
# 17        64.0
# 13        64.0
# 21        64.0
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-634-eb3321260a87> in <module>
#       5 tlb_average, memory_average, tlb_memlist =  getData_average()
#       6
# ----> 7 b, runtime = runMergeSort(memory_average)
#
# <ipython-input-630-64686a69d3a6> in runMergeSort(memory)
#      12     AlignmentLists = [df0,df1,df2,df3,df4,df5,df6]
#      13
# ---> 14     startTime = time.perf_counter()
#      15     ############################################ START TIMING ####################################
#      16     #mergeSort on alignment
#
# UnboundLocalError: local variable 'time' referenced before assignment
