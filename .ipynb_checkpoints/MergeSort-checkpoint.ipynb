# %%
import random
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
NUM_ALIGNMENTS = 7 #number of alignment values (0,4,16,64,256,1024,4096)
tlb = pd.read_csv('tlb.csv')
memory = pd.read_csv('Memory_Sections.csv')

# %%
tlb.columns
# Out:
# Index(['Name', 'Memory Type', 'Min Size', 'Size in KB', 'Start Address'], dtype='object')

# %%
memory
# Out:
#    Name   TLB  Size  Alignment  Start Address
# 0  Mem1  DDR1     3          0            NaN
# 1  Mem1  DDR1     4          0            NaN
# 2  Mem1  DDR1     5          0            NaN
# 3  Mem1  DDR1     1          0            NaN
# 4  Mem1  DDR1     2          0            NaN
# 5  Mem1  DDR1     2          0            NaN

# %%
# merge function
def Merge(a, b, order):
    c = pd.DataFrame(columns = memory.columns)
    while((len(a)!= 0) and (len(b) != 0)):
        if (b.loc[b.first_valid_index()][order] > a.loc[a.first_valid_index()][order]):
            #add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            #remove b[0] from b
            b = b.drop(b.first_valid_index())   
        else:
            # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index())
 
    while (len(a) != 0):     
        # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index()) 
    while (len(b) != 0):     
        # add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            #rmeove a[0] from a
            b = b.drop(b.first_valid_index())  
    return c

# %%
# merge function
def Merge_Backwards(a, b, order):
    c = pd.DataFrame(columns = memory.columns)
    while((len(a)!= 0) and (len(b) != 0)):
        if (b.loc[b.first_valid_index()][order] < a.loc[a.first_valid_index()][order]):
            #add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            #remove b[0] from b
            b = b.drop(b.first_valid_index())   
        else:
            # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index())
 
    while (len(a) != 0):     
        # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index()) 
    while (len(b) != 0):     
        # add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            #rmeove a[0] from a
            b = b.drop(b.first_valid_index())  
    return c

# %%
def MergeSort(mem, order):
    n = len(mem)
    if ( n == 1 ): return mem
    
    l1 = mem[0:math.floor(n/2)]
    l2 = mem[math.floor(n/2) : n]

    l1 = MergeSort( l1, order )
    l2 = MergeSort( l2, order )

    return Merge( l1, l2, order )

# %%
def MergeSort_Backwards(mem, order):
    n = len(mem)
    if ( n == 1 ): return mem
    
    l1 = mem[0:math.floor(n/2)]
    l2 = mem[math.floor(n/2) : n]

    l1 = MergeSort_Backwards( l1, order )
    l2 = MergeSort_Backwards( l2, order )

    return Merge_Backwards( l1, l2, order )

# %%
from numpy import roots
# merge function
def Merge_Alignment(a, b, order):
    # 4,16,64,256,1024,4096
    alignment_cnt = [0,0,0,0,0,0,0]
    c = pd.DataFrame(columns = memory.columns)
    while((len(a)!= 0) and (len(b) != 0)):
        if (b.loc[b.first_valid_index()][order] > a.loc[a.first_valid_index()][order]):
            #add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            alignment_cnt[int(math.log(c.loc[c.last_valid_index()][order], 4))]+=1
            #remove b[0] from b
            b = b.drop(b.first_valid_index())   
        else:
            # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            alignment_cnt[int(math.log(c.loc[c.last_valid_index()][order], 4))]+=1
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index())
 
    while (len(a) != 0):     
        # add a[0] to the end of c
            c = c.append(a.loc[a.first_valid_index()])
            alignment_cnt[int(math.log(c.loc[c.last_valid_index()][order], 4))]+=1
            #rmeove a[0] from a
            a = a.drop(a.first_valid_index()) 
    while (len(b) != 0):     
        # add b[0] to the end of c
            c = c.append(b.loc[b.first_valid_index()])
            alignment_cnt[int(math.log(c.loc[c.last_valid_index()][order], 4))]+=1
            #rmeove a[0] from a
            b = b.drop(b.first_valid_index())  
    
    return c, alignment_cnt

# %%
def MergeSort_Alignment(mem):
    n = len(mem)
    if ( n == 1 ): return mem
    
    l1 = mem[0:math.floor(n/2)]
    l2 = mem[math.floor(n/2) : n]

    l1 = MergeSort( l1, 'Alignment' )
    l2 = MergeSort( l2, 'Alignment' )

    return Merge_Alignment( l1, l2, 'Alignment' )

# %%
#mergeSort on alignment
c, alignment_cnt = MergeSort_Alignment(memory)
print(c, alignment_cnt)
# Out:
# B Size:  256
# A Size:  256
# Added:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# Added:  4
# B Size:  4
# A Size:  4096
# Added:  4096
# Added:  4
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4
# A Size:  1024
# Added:  1024
# Added:  4
# B Size:  4096
# A Size:  256
# Added:  4096
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  256
# A Size:  256
# Added:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# Added:  4
# B Size:  4
# A Size:  4096
# Added:  4096
# Added:  4
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4
# A Size:  1024
# Added:  1024
# Added:  4
# B Size:  4096
# A Size:  256
# Added:  4096
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  4096
# A Size:  4096
# Added:  4096
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  1024
# A Size:  1024
# Added:  1024
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# Added:  4
# B Size:  256
# A Size:  256
# Added:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# Added:  4
# B Size:  4
# A Size:  4096
# Added:  4096
# Added:  4
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4
# A Size:  1024
# Added:  1024
# Added:  4
# B Size:  4096
# A Size:  256
# Added:  4096
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  256
# A Size:  256
# Added:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# Added:  4
# B Size:  4
# A Size:  4096
# Added:  4096
# Added:  4
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4
# A Size:  1024
# Added:  1024
# Added:  4
# B Size:  4096
# A Size:  256
# Added:  4096
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  256
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  4096
# A Size:  4096
# Added:  4096
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  1024
# A Size:  1024
# Added:  1024
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# Added:  4
# B Size:  4096
# A Size:  4096
# Added:  4096
# B Size:  4096
# A Size:  4096
# Added:  4096
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  4096
# A Size:  1024
# Added:  4096
# B Size:  1024
# A Size:  1024
# Added:  1024
# B Size:  1024
# A Size:  1024
# Added:  1024
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  1024
# A Size:  256
# Added:  1024
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  256
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  256
# A Size:  4
# Added:  256
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# Added:  4
# Added:  4
# Added:  4
#      Name   TLB Size Alignment Start Address
# 4    Mem5  DDR1    2      4096           NaN
# 10  Mem11  DDR1    5      4096           NaN
# 16  Mem17  DDR1    3      4096           NaN
# 22  Mem23  DDR1    5      4096           NaN
# 3    Mem4  DDR1    1      1024           NaN
# 9   Mem10  DDR1    4      1024           NaN
# 15  Mem16  DDR1    4      1024           NaN
# 21  Mem22  DDR1    4      1024           NaN
# 1    Mem2  DDR1    4       256           NaN
# 2    Mem3  DDR1    5       256           NaN
# 7    Mem8  DDR1    2       256           NaN
# 8    Mem9  DDR1    3       256           NaN
# 13  Mem14  DDR1    5       256           NaN
# 14  Mem15  DDR1    3       256           NaN
# 19  Mem20  DDR1    4       256           NaN
# 20  Mem21  DDR1    6       256           NaN
# 0    Mem1  DDR1    3         4           NaN
# 5    Mem6  DDR1    2         4           NaN
# 6    Mem7  DDR1    2         4           NaN
# 11  Mem12  DDR1    5         4           NaN
# 12  Mem13  DDR1    5         4           NaN
# 17  Mem18  DDR1    2         4           NaN
# 18  Mem19  DDR1    1         4           NaN
# 23  Mem24  DDR1    5         4           NaN [0, 8, 0, 0, 8, 4, 4]

# %%
#create a list of aligment organized arrays
df0 = pd.DataFrame(columns = memory.columns)
df1 = pd.DataFrame(columns = memory.columns)
df2 = pd.DataFrame(columns = memory.columns)
df3 = pd.DataFrame(columns = memory.columns)
df4 = pd.DataFrame(columns = memory.columns)
df5 = pd.DataFrame(columns = memory.columns)
df6 = pd.DataFrame(columns = memory.columns)

AlignmentLists = [df0,df1,df2,df3,df4,df5,df6]

# %%
#split into data frames by alignment
first = 0
for i in range (NUM_ALIGNMENTS):
    AlignmentLists[NUM_ALIGNMENTS-1-i] = c[first:first+alignment_cnt[NUM_ALIGNMENTS-1-i]]
    first = first + alignment_cnt[NUM_ALIGNMENTS-1-i]

# %%
print(alignment_cnt)
print(AlignmentLists[0], "\n")
print(AlignmentLists[1], "\n")
print(AlignmentLists[2], "\n")
print(AlignmentLists[3], "\n")
print(AlignmentLists[4], "\n")
print(AlignmentLists[5], "\n")
print(AlignmentLists[6], "\n")
# Out:
# [0, 8, 0, 0, 8, 4, 4]
# Empty DataFrame
# Columns: [Name, TLB, Size, Alignment, Start Address]
# Index: []
#
#      Name   TLB Size Alignment Start Address
# 0    Mem1  DDR1    3         4           NaN
# 5    Mem6  DDR1    2         4           NaN
# 6    Mem7  DDR1    2         4           NaN
# 11  Mem12  DDR1    5         4           NaN
# 12  Mem13  DDR1    5         4           NaN
# 17  Mem18  DDR1    2         4           NaN
# 18  Mem19  DDR1    1         4           NaN
# 23  Mem24  DDR1    5         4           NaN
#
# Empty DataFrame
# Columns: [Name, TLB, Size, Alignment, Start Address]
# Index: []
#
# Empty DataFrame
# Columns: [Name, TLB, Size, Alignment, Start Address]
# Index: []
#
#      Name   TLB Size Alignment Start Address
# 1    Mem2  DDR1    4       256           NaN
# 2    Mem3  DDR1    5       256           NaN
# 7    Mem8  DDR1    2       256           NaN
# 8    Mem9  DDR1    3       256           NaN
# 13  Mem14  DDR1    5       256           NaN
# 14  Mem15  DDR1    3       256           NaN
# 19  Mem20  DDR1    4       256           NaN
# 20  Mem21  DDR1    6       256           NaN
#
#      Name   TLB Size Alignment Start Address
# 3    Mem4  DDR1    1      1024           NaN
# 9   Mem10  DDR1    4      1024           NaN
# 15  Mem16  DDR1    4      1024           NaN
# 21  Mem22  DDR1    4      1024           NaN
#
#      Name   TLB Size Alignment Start Address
# 4    Mem5  DDR1    2      4096           NaN
# 10  Mem11  DDR1    5      4096           NaN
# 16  Mem17  DDR1    3      4096           NaN
# 22  Mem23  DDR1    5      4096           NaN

# %%
#sort each alignment df by size in decending order
order = 'Size'
for i in range (NUM_ALIGNMENTS):
    if(len(AlignmentLists[i])>1):
        AlignmentLists[i] = MergeSort(AlignmentLists[i], order)
# Out:
# B Size:  2
# A Size:  3
# Added:  3
# Added:  2
# B Size:  5
# A Size:  2
# Added:  5
# Added:  2
# B Size:  5
# A Size:  3
# Added:  5
# B Size:  2
# A Size:  3
# Added:  3
# B Size:  2
# A Size:  2
# Added:  2
# Added:  2
# B Size:  2
# A Size:  5
# Added:  5
# Added:  2
# B Size:  5
# A Size:  1
# Added:  5
# Added:  1
# B Size:  5
# A Size:  5
# Added:  5
# B Size:  5
# A Size:  2
# Added:  5
# B Size:  1
# A Size:  2
# Added:  2
# Added:  1
# B Size:  5
# A Size:  5
# Added:  5
# B Size:  5
# A Size:  3
# Added:  5
# B Size:  5
# A Size:  3
# Added:  5
# B Size:  2
# A Size:  3
# Added:  3
# B Size:  2
# A Size:  2
# Added:  2
# B Size:  2
# A Size:  2
# Added:  2
# Added:  2
# Added:  1
# B Size:  5
# A Size:  4
# Added:  5
# Added:  4
# B Size:  3
# A Size:  2
# Added:  3
# Added:  2
# B Size:  3
# A Size:  5
# Added:  5
# B Size:  3
# A Size:  4
# Added:  4
# Added:  3
# Added:  2
# B Size:  3
# A Size:  5
# Added:  5
# Added:  3
# B Size:  6
# A Size:  4
# Added:  6
# Added:  4
# B Size:  6
# A Size:  5
# Added:  6
# B Size:  4
# A Size:  5
# Added:  5
# B Size:  4
# A Size:  3
# Added:  4
# Added:  3
# B Size:  6
# A Size:  5
# Added:  6
# B Size:  5
# A Size:  5
# Added:  5
# B Size:  5
# A Size:  4
# Added:  5
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  3
# Added:  4
# B Size:  3
# A Size:  3
# Added:  3
# B Size:  3
# A Size:  2
# Added:  3
# Added:  2
# B Size:  4
# A Size:  1
# Added:  4
# Added:  1
# B Size:  4
# A Size:  4
# Added:  4
# Added:  4
# B Size:  4
# A Size:  4
# Added:  4
# B Size:  4
# A Size:  1
# Added:  4
# B Size:  4
# A Size:  1
# Added:  4
# Added:  1
# B Size:  5
# A Size:  2
# Added:  5
# Added:  2
# B Size:  5
# A Size:  3
# Added:  5
# Added:  3
# B Size:  5
# A Size:  5
# Added:  5
# B Size:  5
# A Size:  2
# Added:  5
# B Size:  3
# A Size:  2
# Added:  3
# Added:  2

# %%
#getNextMinAddress returns the next min address possible for the specified entry i in the current Align List
def getNextStartAddress(AlignList, i):
    if(i==0):
        #assign address to min TLB value, for now use 0
        StartAddress = 0 
    else:
        min_address = (AlignList.iloc[i-1]['Start Address'] + AlignList.iloc[i-1]['Size'])
        alignment = AlignList.iloc[i]['Alignment']
        StartAddress = (min_address + alignment) - (min_address + alignment)%alignment
    return StartAddress

# %%
#assign start addresses starting from largest to smallest and merge
for i in range (NUM_ALIGNMENTS):
    if (len(AlignmentLists[NUM_ALIGNMENTS-1-i])!=0):
        first_nonzero = i
        break
for j in range(len(AlignmentLists[NUM_ALIGNMENTS-1-i])):
    AlignmentLists[NUM_ALIGNMENTS-1-i].iloc[j]['Start Address'] = getNextStartAddress(AlignmentLists[NUM_ALIGNMENTS-1-i],j)
print(AlignmentLists[NUM_ALIGNMENTS-1-i])
# Out:
#      Name   TLB Size Alignment Start Address
# 10  Mem11  DDR1    5      4096             0
# 22  Mem23  DDR1    5      4096          4096
# 16  Mem17  DDR1    3      4096          8192
# 4    Mem5  DDR1    2      4096         12288

# %%
#getNextMinAddress returns the next min address possible for the specified entry i in the current Align List
def getNextStartAddress_Merge(AlignList, i, alignment):
    if(i==0):
        #assign address to min TLB value, for now use 0
        StartAddress = 0 
    else:
        min_address = (AlignList.iloc[i]['Start Address'] + AlignList.iloc[i]['Size'])
        StartAddress = (min_address + alignment) - (min_address + alignment)%alignment
    return StartAddress

# %%
# merge function
#b has addresses 
#a does not have addresses
def MergeAssignAddress(a, b, order):
    c = pd.DataFrame(columns = memory.columns)
    #assign first to b
    if(len(b)>0):
        #add b[0] to the end of c
        c = c.append(b.loc[b.first_valid_index()])
        #remove b[0] from b
        b = b.drop(b.first_valid_index()) 
    while((len(a)!= 0) and (len(b) != 0)):        
        #assign a address to the earliest possible next address in c
       # a.loc[a.first_valid_index()][order] =  c.loc[-1][order] +  c.loc[-1]['Size']
        a.loc[a.first_valid_index()][order] = getNextStartAddress_Merge(c, len(c)-1, a.loc[a.first_valid_index()]['Alignment'] )
        if(len(b)>1):
            if(a.loc[a.first_valid_index()][order] + a.loc[a.first_valid_index()]['Size'] > b.loc[b.first_valid_index()][order]):
                #add b[0] to the end of c
                c = c.append(b.loc[b.first_valid_index()])
                #remove b[0] from b
                b = b.drop(b.first_valid_index())   
            else:
                # add a[0] to the end of c
                c = c.append(a.loc[a.first_valid_index()])
                #rmeove a[0] from a
                a = a.drop(a.first_valid_index())

    while (len(a) != 0):     
        #assign a
        #assign a address to the earliest possible next address in c
        #a.loc[a.first_valid_index()][order] =  c.loc[-1][order] +  c.loc[-1]['Size']
        a.loc[a.first_valid_index()][order] = getNextStartAddress_Merge(c, len(c)-1, a.loc[a.first_valid_index()]['Alignment'] )
        # add a[0] to the end of c
        c = c.append(a.loc[a.first_valid_index()])
        #rmeove a[0] from a
        a = a.drop(a.first_valid_index()) 
    while (len(b) != 0):     
        # add b[0] to the end of c
        c = c.append(b.loc[b.first_valid_index()])
        #rmeove a[0] from a
        b = b.drop(b.first_valid_index())  
    return c

# %%
def MergeSort_AssignAddress(mem):
    n = len(mem)
    if ( n == 1 ): return mem
    
    l1 = mem[0:math.floor(n/2)]
    l2 = mem[math.floor(n/2) : n]

    l1 = MergeSort_AssignAddress( l1, 'Start Address' )
    l2 = MergeSort_AssignAddress( l2, 'Start Address' )

    return MergeAssignAddress( l1, l2, 'Start Address' )

# %%
b = AlignmentLists[NUM_ALIGNMENTS-1-first_nonzero]
for j in range(first_nonzero+1,NUM_ALIGNMENTS):
    print(NUM_ALIGNMENTS-j-first_nonzero)
    a = AlignmentLists[NUM_ALIGNMENTS-1-j-first_nonzero]
    b = MergeAssignAddress(a, b, 'Start Address')
# Out:
# 6
# Added:  0
# B Size:  5
# A Size:  4
# 0
# 4
# 4096
# Added:  0
# B Size:  5
# A Size:  4
# 1028
# 4096
# Added:  1024
# B Size:  5
# A Size:  4
# 2052
# 4096
# Added:  2048
# B Size:  5
# A Size:  1
# 3073
# 4096
# Added:  3072
# Added:  4096
# Added:  8192
# Added:  12288
# 5
# Added:  0
# B Size:  4
# A Size:  6
# 0
# 6
# 0
# Added:  0
# B Size:  4
# A Size:  6
# 262
# 1024
# Added:  256
# B Size:  4
# A Size:  5
# 517
# 1024
# Added:  512
# B Size:  4
# A Size:  5
# 773
# 1024
# Added:  768
# B Size:  4
# A Size:  4
# 1028
# 1024
# Added:  1024
# B Size:  4
# A Size:  4
# 1284
# 2048
# Added:  1280
# B Size:  4
# A Size:  4
# 1540
# 2048
# Added:  1536
# B Size:  4
# A Size:  3
# 1795
# 2048
# Added:  1792
# B Size:  4
# A Size:  3
# 2051
# 2048
# Added:  2048
# B Size:  1
# A Size:  3
# 2307
# 3072
# Added:  2304
# B Size:  1
# A Size:  2
# 2562
# 3072
# Added:  2560
# Added:  3072
# Added:  4096
# Added:  8192
# Added:  12288
# 4
# Added:  0
# Added:  0
# Added:  256
# Added:  512
# Added:  768
# Added:  1024
# Added:  1280
# Added:  1536
# Added:  1792
# Added:  2048
# Added:  2304
# Added:  2560
# Added:  3072
# Added:  4096
# Added:  8192
# Added:  12288
# 3
# Added:  0
# Added:  0
# Added:  256
# Added:  512
# Added:  768
# Added:  1024
# Added:  1280
# Added:  1536
# Added:  1792
# Added:  2048
# Added:  2304
# Added:  2560
# Added:  3072
# Added:  4096
# Added:  8192
# Added:  12288
# 2
# Added:  0
# B Size:  4
# A Size:  5
# 0
# 5
# 0
# Added:  0
# B Size:  6
# A Size:  5
# 13
# 256
# Added:  8
# B Size:  6
# A Size:  5
# 21
# 256
# Added:  16
# B Size:  6
# A Size:  5
# 29
# 256
# Added:  24
# B Size:  6
# A Size:  3
# 35
# 256
# Added:  32
# B Size:  6
# A Size:  2
# 38
# 256
# Added:  36
# B Size:  6
# A Size:  2
# 42
# 256
# Added:  40
# B Size:  6
# A Size:  2
# 46
# 256
# Added:  44
# B Size:  6
# A Size:  1
# 49
# 256
# Added:  48
# Added:  256
# Added:  512
# Added:  768
# Added:  1024
# Added:  1280
# Added:  1536
# Added:  1792
# Added:  2048
# Added:  2304
# Added:  2560
# Added:  3072
# Added:  4096
# Added:  8192
# Added:  12288
# 1
# Added:  0
# Added:  0
# Added:  8
# Added:  16
# Added:  24
# Added:  32
# Added:  36
# Added:  40
# Added:  44
# Added:  48
# Added:  256
# Added:  512
# Added:  768
# Added:  1024
# Added:  1280
# Added:  1536
# Added:  1792
# Added:  2048
# Added:  2304
# Added:  2560
# Added:  3072
# Added:  4096
# Added:  8192
# Added:  12288

# %%
print(b)
# Out:
#      Name   TLB Size Alignment Start Address
# 10  Mem11  DDR1    5      4096             0
# 9   Mem10  DDR1    4      1024             0
# 11  Mem12  DDR1    5         4             8
# 12  Mem13  DDR1    5         4            16
# 23  Mem24  DDR1    5         4            24
# 0    Mem1  DDR1    3         4            32
# 5    Mem6  DDR1    2         4            36
# 6    Mem7  DDR1    2         4            40
# 17  Mem18  DDR1    2         4            44
# 18  Mem19  DDR1    1         4            48
# 20  Mem21  DDR1    6       256           256
# 2    Mem3  DDR1    5       256           512
# 13  Mem14  DDR1    5       256           768
# 15  Mem16  DDR1    4      1024          1024
# 1    Mem2  DDR1    4       256          1280
# 19  Mem20  DDR1    4       256          1536
# 8    Mem9  DDR1    3       256          1792
# 21  Mem22  DDR1    4      1024          2048
# 14  Mem15  DDR1    3       256          2304
# 7    Mem8  DDR1    2       256          2560
# 3    Mem4  DDR1    1      1024          3072
# 22  Mem23  DDR1    5      4096          4096
# 16  Mem17  DDR1    3      4096          8192
# 4    Mem5  DDR1    2      4096         12288

# %%
tlb_memlist = []
temp = pd.DataFrame(columns = tlb.columns)
temp2 = pd.DataFrame(columns = tlb.columns)
for i in range(num_tlbs):
    temp = (memory_average.loc[memory_average['TLB'] == tlb.iloc[i]['Name']])
    temp2 = temp.copy()
    tlb_memlist.append(temp)
    # memory_average.loc[memory_average['TLB'] == 'User_TLB_DDR_3_1']
memory = tlb_memlist[0]
memory = memory_average
print(temp2)
# Out:
#                                    Name               TLB   Size Alignment  \
# 21   Memory_Section_User_TLB_DDR_6_4_32  User_TLB_DDR_6_4  0x33c    0x1000
# 32    Memory_Section_User_TLB_DDR_6_4_8  User_TLB_DDR_6_4  0x5e0      0x10
# 51    Memory_Section_User_TLB_DDR_6_4_0  User_TLB_DDR_6_4  0xb01    0x1000
# 75   Memory_Section_User_TLB_DDR_6_4_11  User_TLB_DDR_6_4   0x8b     0x400
# 76   Memory_Section_User_TLB_DDR_6_4_36  User_TLB_DDR_6_4  0x992     0x400
# 138   Memory_Section_User_TLB_DDR_6_4_3  User_TLB_DDR_6_4  0xc4d      0x10
# 152  Memory_Section_User_TLB_DDR_6_4_22  User_TLB_DDR_6_4  0x3b5      0x40
# 153   Memory_Section_User_TLB_DDR_6_4_9  User_TLB_DDR_6_4   0x1a     0x100
# 165  Memory_Section_User_TLB_DDR_6_4_21  User_TLB_DDR_6_4   0x59      0x40
# 204   Memory_Section_User_TLB_DDR_6_4_6  User_TLB_DDR_6_4  0x172      0x40
# 215  Memory_Section_User_TLB_DDR_6_4_34  User_TLB_DDR_6_4  0xa7b      0x40
# 226  Memory_Section_User_TLB_DDR_6_4_19  User_TLB_DDR_6_4  0x685     0x400
# 265  Memory_Section_User_TLB_DDR_6_4_18  User_TLB_DDR_6_4  0x936     0x100
# 274   Memory_Section_User_TLB_DDR_6_4_4  User_TLB_DDR_6_4  0x8ea     0x400
# 339  Memory_Section_User_TLB_DDR_6_4_30  User_TLB_DDR_6_4  0xa85       0x4
# 393  Memory_Section_User_TLB_DDR_6_4_13  User_TLB_DDR_6_4  0xaf0      0x40
# 396  Memory_Section_User_TLB_DDR_6_4_29  User_TLB_DDR_6_4  0x1ef     0x400
# 411  Memory_Section_User_TLB_DDR_6_4_25  User_TLB_DDR_6_4  0xa67     0x100
# 448  Memory_Section_User_TLB_DDR_6_4_35  User_TLB_DDR_6_4  0x3d8    0x1000
# 497  Memory_Section_User_TLB_DDR_6_4_27  User_TLB_DDR_6_4  0xc0f      0x10
# 518   Memory_Section_User_TLB_DDR_6_4_7  User_TLB_DDR_6_4  0xa1c    0x1000
# 531  Memory_Section_User_TLB_DDR_6_4_26  User_TLB_DDR_6_4  0x77c     0x400
# 551  Memory_Section_User_TLB_DDR_6_4_17  User_TLB_DDR_6_4  0x2fe     0x400
# 603  Memory_Section_User_TLB_DDR_6_4_14  User_TLB_DDR_6_4  0x345     0x400
# 674  Memory_Section_User_TLB_DDR_6_4_15  User_TLB_DDR_6_4  0x987     0x100
# 676  Memory_Section_User_TLB_DDR_6_4_31  User_TLB_DDR_6_4  0x879     0x400
# 679  Memory_Section_User_TLB_DDR_6_4_33  User_TLB_DDR_6_4  0x9a7      0x10
# 724  Memory_Section_User_TLB_DDR_6_4_28  User_TLB_DDR_6_4  0xa6d      0x10
# 741   Memory_Section_User_TLB_DDR_6_4_1  User_TLB_DDR_6_4  0x701       0x4
# 792  Memory_Section_User_TLB_DDR_6_4_20  User_TLB_DDR_6_4  0x709     0x400
# 801   Memory_Section_User_TLB_DDR_6_4_5  User_TLB_DDR_6_4  0x5de     0x400
# 808  Memory_Section_User_TLB_DDR_6_4_10  User_TLB_DDR_6_4   0x47      0x40
# 810  Memory_Section_User_TLB_DDR_6_4_16  User_TLB_DDR_6_4  0x688     0x100
# 831  Memory_Section_User_TLB_DDR_6_4_24  User_TLB_DDR_6_4  0x821     0x400
# 867  Memory_Section_User_TLB_DDR_6_4_23  User_TLB_DDR_6_4  0x605    0x1000
#
#     Start Address
# 21     0x55134000
# 32     0x5513ecc0
# 51     0x55130000
# 75     0x55138400
# 76     0x55133400
# 138    0x5513c040
# 152    0x55136440
# 153    0x55131b00
# 165    0x55130b40
# 204    0x55132640
# 215    0x5513b5c0
# 226    0x55137000
# 265    0x55139a00
# 274    0x55134400
# 339    0x5513f2a0
# 393    0x5513aac0
# 396    0x55138000
# 411    0x55138500
# 448    0x55133000
# 497    0x5513cc90
# 518    0x55131000
# 531    0x55132800
# 551    0x55131c00
# 603    0x55130c00
# 674    0x55139000
# 676    0x55135000
# 679    0x5513e310
# 724    0x5513d8a0
# 741    0x5513fd28
# 792    0x55136800
# 801    0x55137800
# 808    0x55130f80
# 810    0x5513a400
# 831    0x55135c00
# 867    0x55132000

# %%
#FOR TIMING
#memory = pd.read_csv('Memory_Sections.csv')
############################################ START TIMING ####################################
#mergeSort on alignment
c, alignment_cnt = MergeSort_Alignment(memory)

#split into data frames by alignment
first = 0
for i in range (NUM_ALIGNMENTS):
    AlignmentLists[NUM_ALIGNMENTS-1-i] = c[first:first+alignment_cnt[NUM_ALIGNMENTS-1-i]]
    first = first + alignment_cnt[NUM_ALIGNMENTS-1-i]
    
#sort each alignment df by size in decending order
order = 'Size'
for i in range (NUM_ALIGNMENTS):
    if(len(AlignmentLists[i])>1):
        AlignmentLists[i] = MergeSort(AlignmentLists[i], order)    
    
#assign start addresses starting from largest to smallest and merge
for i in range (NUM_ALIGNMENTS):
    if (len(AlignmentLists[NUM_ALIGNMENTS-1-i])!=0):
        first_nonzero = i
        break
for j in range(len(AlignmentLists[NUM_ALIGNMENTS-1-i])):
    AlignmentLists[NUM_ALIGNMENTS-1-i].set_value(AlignmentLists[NUM_ALIGNMENTS-1-i].index[j], 'Start Address',getNextStartAddress(AlignmentLists[NUM_ALIGNMENTS-1-i],j))

#merge all
b = AlignmentLists[NUM_ALIGNMENTS-1-first_nonzero]
for j in range(first_nonzero+1,NUM_ALIGNMENTS):
    a = AlignmentLists[NUM_ALIGNMENTS-1-j-first_nonzero]
    b = MergeAssignAddress(a, b, 'Start Address')
############################################ END TIMING ####################################
print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-561-724cfb1d1510> in <module>
#       3 ############################################ START TIMING ####################################
#       4 #mergeSort on alignment
# ----> 5 c, alignment_cnt = MergeSort_Alignment(memory)
#       6
#       7 #split into data frames by alignment
#
# <ipython-input-453-b7d325a464fb> in MergeSort_Alignment(mem)
#       9     l2 = MergeSort( l2, 'Alignment' )
#      10
# ---> 11     return Merge_Alignment( l1, l2, 'Alignment' )
#
# <ipython-input-452-0365b0a94aed> in Merge_Alignment(a, b, order)
#      15             # add a[0] to the end of c
#      16             c = c.append(a.loc[a.first_valid_index()])
# ---> 17             alignment_cnt[int(math.log(c.loc[c.last_valid_index()][order], 4))]+=1
#      18             #rmeove a[0] from a
#      19             a = a.drop(a.first_valid_index())
#
# TypeError: must be real number, not str

# %%
tlbs_average =  pd.read_csv('generated_tlbs_average_case.csv')
memory_average = pd.read_csv('generated_memory_sections_average_case.csv')
print(tlbs_average)
print(memory_average)
# Out:
#                 Name   Min Size Size In KB Start Address
# 0   User_TLB_DDR_5_4    0x196ef      0x100    0x55080000
# 1   User_TLB_DDR_3_3   0xc026ef     0x4000    0x50000000
# 2   User_TLB_DDR_1_3  0x6677e21    0x40000    0x20000000
# 3   User_TLB_DDR_5_0    0x1677b      0x100    0x550c0000
# 4   User_TLB_DDR_2_0  0x3125260    0x10000    0x40000000
# 5   User_TLB_DDR_6_0     0x85ef       0x40    0x55120000
# 6   User_TLB_DDR_4_0   0x15c913     0x1000    0x54c00000
# 7   User_TLB_DDR_4_4   0x3d5943     0x1000    0x54000000
# 8   User_TLB_DDR_4_2   0x297183     0x1000    0x54800000
# 9   User_TLB_DDR_6_5     0xa540       0x40    0x55110000
# 10  User_TLB_DDR_2_2  0x2ce757d    0x10000    0x44000000
# 11  User_TLB_DDR_3_4   0xaa68f5     0x4000    0x52000000
# 12  User_TLB_DDR_4_3   0x32ef83     0x1000    0x54400000
# 13  User_TLB_DDR_6_4     0x6168       0x40    0x55130000
# 14  User_TLB_DDR_2_1  0x1945dc3    0x10000    0x48000000
# 15  User_TLB_DDR_6_1     0xb561       0x40    0x55100000
# 16  User_TLB_DDR_1_0  0xb7b6922    0x40000    0x10000000
# 17  User_TLB_DDR_5_1    0x313d3      0x100    0x55000000
# 18  User_TLB_DDR_1_4  0xf3bde42    0x40000           0x0
# 19  User_TLB_DDR_5_2    0x28f27      0x100    0x55040000
# 20  User_TLB_DDR_3_0   0xb6c96b     0x4000    0x51000000
# 21  User_TLB_DDR_3_1   0x557d38     0x4000    0x53000000
# 22  User_TLB_DDR_1_1  0x5790b9a    0x40000    0x30000000
# 23  User_TLB_DDR_2_3  0x17e5578    0x10000    0x4c000000
#                                    Name               TLB      Size Alignment  \
# 0     Memory_Section_User_TLB_DDR_4_3_8  User_TLB_DDR_4_3   0x107b0    0x1000
# 1    Memory_Section_User_TLB_DDR_5_1_22  User_TLB_DDR_5_1    0x1f03     0x100
# 2     Memory_Section_User_TLB_DDR_4_0_9  User_TLB_DDR_4_0   0x1a712       0x4
# 3    Memory_Section_User_TLB_DDR_1_1_13  User_TLB_DDR_1_1  0x9a64a0      0x40
# 4    Memory_Section_User_TLB_DDR_5_0_32  User_TLB_DDR_5_0    0x20d4      0x10
# 5    Memory_Section_User_TLB_DDR_5_4_19  User_TLB_DDR_5_4     0x387     0x400
# 6    Memory_Section_User_TLB_DDR_1_3_14  User_TLB_DDR_1_3  0x7000cd     0x400
# 7    Memory_Section_User_TLB_DDR_6_1_29  User_TLB_DDR_6_1     0x43c    0x1000
# 8     Memory_Section_User_TLB_DDR_6_5_7  User_TLB_DDR_6_5     0xc6f     0x100
# 9    Memory_Section_User_TLB_DDR_3_4_28  User_TLB_DDR_3_4   0x77566    0x1000
# 10   Memory_Section_User_TLB_DDR_5_0_13  User_TLB_DDR_5_0    0x15f1      0x40
# 11   Memory_Section_User_TLB_DDR_6_1_23  User_TLB_DDR_6_1     0x8fc      0x40
# 12   Memory_Section_User_TLB_DDR_5_1_11  User_TLB_DDR_5_1    0x2d44    0x1000
# 13   Memory_Section_User_TLB_DDR_1_0_27  User_TLB_DDR_1_0  0xaf4b9f    0x1000
# 14   Memory_Section_User_TLB_DDR_2_3_41  User_TLB_DDR_2_3  0x2f5714      0x40
# 15   Memory_Section_User_TLB_DDR_3_3_26  User_TLB_DDR_3_3   0x521ce      0x40
# 16   Memory_Section_User_TLB_DDR_2_0_11  User_TLB_DDR_2_0  0x1115c8       0x4
# 17   Memory_Section_User_TLB_DDR_1_4_34  User_TLB_DDR_1_4  0x5c9911     0x400
# 18   Memory_Section_User_TLB_DDR_5_1_33  User_TLB_DDR_5_1    0x1b8a     0x100
# 19   Memory_Section_User_TLB_DDR_4_4_28  User_TLB_DDR_4_4   0x28985    0x1000
# 20    Memory_Section_User_TLB_DDR_2_2_5  User_TLB_DDR_2_2   0x8a416    0x1000
# 21   Memory_Section_User_TLB_DDR_6_4_32  User_TLB_DDR_6_4     0x33c    0x1000
# 22   Memory_Section_User_TLB_DDR_1_0_29  User_TLB_DDR_1_0  0x722a61      0x10
# 23    Memory_Section_User_TLB_DDR_6_0_8  User_TLB_DDR_6_0     0xa69       0x4
# 24   Memory_Section_User_TLB_DDR_4_0_29  User_TLB_DDR_4_0   0x1850b      0x10
# 25   Memory_Section_User_TLB_DDR_3_3_14  User_TLB_DDR_3_3   0x747ae    0x1000
# 26   Memory_Section_User_TLB_DDR_3_4_15  User_TLB_DDR_3_4   0xb7420       0x4
# 27   Memory_Section_User_TLB_DDR_1_4_35  User_TLB_DDR_1_4   0x6afd9      0x40
# 28   Memory_Section_User_TLB_DDR_1_0_39  User_TLB_DDR_1_0  0x94653f     0x100
# 29    Memory_Section_User_TLB_DDR_3_1_4  User_TLB_DDR_3_1   0x38923      0x10
# ..                                  ...               ...       ...       ...
# 881  Memory_Section_User_TLB_DDR_3_4_29  User_TLB_DDR_3_4   0x43ac1     0x100
# 882   Memory_Section_User_TLB_DDR_4_4_1  User_TLB_DDR_4_4   0x2b022     0x100
# 883  Memory_Section_User_TLB_DDR_5_1_15  User_TLB_DDR_5_1    0x2360      0x40
# 884  Memory_Section_User_TLB_DDR_2_3_17  User_TLB_DDR_2_3  0x15b32a      0x40
# 885  Memory_Section_User_TLB_DDR_3_4_32  User_TLB_DDR_3_4   0x2c973     0x400
# 886  Memory_Section_User_TLB_DDR_6_5_25  User_TLB_DDR_6_5     0x2d2      0x10
# 887   Memory_Section_User_TLB_DDR_3_1_8  User_TLB_DDR_3_1   0x58514     0x400
# 888  Memory_Section_User_TLB_DDR_2_2_38  User_TLB_DDR_2_2  0x2997a3      0x40
# 889   Memory_Section_User_TLB_DDR_4_4_8  User_TLB_DDR_4_4   0x275df       0x4
# 890  Memory_Section_User_TLB_DDR_5_0_36  User_TLB_DDR_5_0    0x1a48      0x10
# 891  Memory_Section_User_TLB_DDR_3_0_11  User_TLB_DDR_3_0   0xc4093       0x4
# 892  Memory_Section_User_TLB_DDR_4_0_12  User_TLB_DDR_4_0   0x1e38b     0x400
# 893  Memory_Section_User_TLB_DDR_3_0_39  User_TLB_DDR_3_0   0x3a187     0x100
# 894   Memory_Section_User_TLB_DDR_1_0_8  User_TLB_DDR_1_0  0x1e5499    0x1000
# 895  Memory_Section_User_TLB_DDR_2_0_35  User_TLB_DDR_2_0  0x26708a    0x1000
# 896   Memory_Section_User_TLB_DDR_5_0_9  User_TLB_DDR_5_0    0x2667       0x4
# 897  Memory_Section_User_TLB_DDR_5_2_30  User_TLB_DDR_5_2    0x2c72    0x1000
# 898  Memory_Section_User_TLB_DDR_1_3_18  User_TLB_DDR_1_3    0xcd3e      0x10
# 899  Memory_Section_User_TLB_DDR_2_2_27  User_TLB_DDR_2_2    0x15a5    0x1000
# 900  Memory_Section_User_TLB_DDR_1_4_16  User_TLB_DDR_1_4  0x9bde8a      0x10
# 901  Memory_Section_User_TLB_DDR_6_0_30  User_TLB_DDR_6_0     0xcac      0x10
# 902   Memory_Section_User_TLB_DDR_1_1_0  User_TLB_DDR_1_1  0x7239cf     0x100
# 903  Memory_Section_User_TLB_DDR_6_0_15  User_TLB_DDR_6_0     0x8e1     0x400
# 904  Memory_Section_User_TLB_DDR_4_4_12  User_TLB_DDR_4_4   0x1ec26     0x100
# 905   Memory_Section_User_TLB_DDR_5_0_5  User_TLB_DDR_5_0    0x192f     0x100
# 906   Memory_Section_User_TLB_DDR_3_1_0  User_TLB_DDR_3_1   0x24096    0x1000
# 907  Memory_Section_User_TLB_DDR_2_0_12  User_TLB_DDR_2_0   0x3b042      0x10
# 908  Memory_Section_User_TLB_DDR_4_4_26  User_TLB_DDR_4_4   0x2748b       0x4
# 909  Memory_Section_User_TLB_DDR_3_0_24  User_TLB_DDR_3_0    0x448e    0x1000
# 910  Memory_Section_User_TLB_DDR_1_1_38  User_TLB_DDR_1_1  0x5c7406       0x4
#
#     Start Address
# 0      0x54475000
# 1      0x55024b00
# 2      0x54fe5900
# 3      0x36436740
# 4      0x550f09f0
# 5      0x55098400
# 6      0x2571c400
# 7      0x55107000
# 8      0x55117100
# 9      0x52315000
# 10     0x550e7180
# 11     0x55105580
# 12     0x55004000
# 13     0x10000000
# 14     0x4d5f1a80
# 15     0x50bfdf40
# 16     0x43e79fa4
# 17      0x4ff5800
# 18     0x55026b00
# 19     0x54062000
# 20     0x44929000
# 21     0x55134000
# 22     0x1d4871a0
# 23     0x5512d70c
# 24     0x54ed4420
# 25     0x5028d000
# 26     0x52cf0e10
# 27      0xbaacd80
# 28     0x14dbe500
# 29     0x53b9bf70
# ..            ...
# 881    0x52b08000
# 882    0x5410fe00
# 883    0x550328c0
# 884    0x4de99b80
# 885    0x527f4400
# 886    0x5511d340
# 887    0x533ecc00
# 888    0x462ce040
# 889    0x542b8010
# 890    0x550f2ad0
# 891    0x51d55660
# 892    0x54d24400
# 893    0x51998c00
# 894    0x131fa000
# 895    0x405b5000
# 896    0x550fbe90
# 897    0x55048000
# 898    0x2ebdf8f0
# 899    0x449b4000
# 900     0xc627dd0
# 901    0x55129740
# 902    0x341be900
# 903    0x55122400
# 904    0x54182000
# 905    0x550daa00
# 906    0x531db000
# 907    0x42e05fb0
# 908    0x542df5f0
# 909    0x51347000
# 910    0x3fb84834
#
# [911 rows x 5 columns]

# %%
tlb = tlbs_average
tlb = MergeSort_Backwards(tlb, 'Start Address')
print(tlb)
num_tlbs = len(tlb)
# Out:
#                 Name  TLB Size Alignment Start Address   Min Size Size In KB
# 18  User_TLB_DDR_1_4  NaN  NaN       NaN           0x0  0xf3bde42    0x40000
# 16  User_TLB_DDR_1_0  NaN  NaN       NaN    0x10000000  0xb7b6922    0x40000
# 2   User_TLB_DDR_1_3  NaN  NaN       NaN    0x20000000  0x6677e21    0x40000
# 22  User_TLB_DDR_1_1  NaN  NaN       NaN    0x30000000  0x5790b9a    0x40000
# 4   User_TLB_DDR_2_0  NaN  NaN       NaN    0x40000000  0x3125260    0x10000
# 10  User_TLB_DDR_2_2  NaN  NaN       NaN    0x44000000  0x2ce757d    0x10000
# 14  User_TLB_DDR_2_1  NaN  NaN       NaN    0x48000000  0x1945dc3    0x10000
# 23  User_TLB_DDR_2_3  NaN  NaN       NaN    0x4c000000  0x17e5578    0x10000
# 1   User_TLB_DDR_3_3  NaN  NaN       NaN    0x50000000   0xc026ef     0x4000
# 20  User_TLB_DDR_3_0  NaN  NaN       NaN    0x51000000   0xb6c96b     0x4000
# 11  User_TLB_DDR_3_4  NaN  NaN       NaN    0x52000000   0xaa68f5     0x4000
# 21  User_TLB_DDR_3_1  NaN  NaN       NaN    0x53000000   0x557d38     0x4000
# 7   User_TLB_DDR_4_4  NaN  NaN       NaN    0x54000000   0x3d5943     0x1000
# 12  User_TLB_DDR_4_3  NaN  NaN       NaN    0x54400000   0x32ef83     0x1000
# 8   User_TLB_DDR_4_2  NaN  NaN       NaN    0x54800000   0x297183     0x1000
# 6   User_TLB_DDR_4_0  NaN  NaN       NaN    0x54c00000   0x15c913     0x1000
# 17  User_TLB_DDR_5_1  NaN  NaN       NaN    0x55000000    0x313d3      0x100
# 19  User_TLB_DDR_5_2  NaN  NaN       NaN    0x55040000    0x28f27      0x100
# 0   User_TLB_DDR_5_4  NaN  NaN       NaN    0x55080000    0x196ef      0x100
# 3   User_TLB_DDR_5_0  NaN  NaN       NaN    0x550c0000    0x1677b      0x100
# 15  User_TLB_DDR_6_1  NaN  NaN       NaN    0x55100000     0xb561       0x40
# 9   User_TLB_DDR_6_5  NaN  NaN       NaN    0x55110000     0xa540       0x40
# 5   User_TLB_DDR_6_0  NaN  NaN       NaN    0x55120000     0x85ef       0x40
# 13  User_TLB_DDR_6_4  NaN  NaN       NaN    0x55130000     0x6168       0x40

# %%
tlb_memlist = []
temp = pd.DataFrame()
for i in range(num_tlbs):
    temp = (memory_average.loc[memory_average['TLB'] == tlb.iloc[i]['Name']])
    tlb_memlist.append(temp)
    # memory_average.loc[memory_average['TLB'] == 'User_TLB_DDR_3_1']

# %%
memory_average.loc[memory_average['TLB'] == 'User_TLB_DDR_3_1']
